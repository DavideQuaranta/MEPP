# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import params as my
from IPython.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# %config InlineBackend.figure_format = 'svg'
# Out:
# <style>.container { width:98% !important; }</style>

# %%
data = pd.read_csv('data.csv')

# %%
vtx = data['# vtx with two tracks of opposite curvature'].to_numpy()
x = data['XV (cm)'].to_numpy()
y = data['YV(cm)'].to_numpy()
z = data['ZV(cm)'].to_numpy()
px1 = data['Track1 PX(MeV) '].to_numpy()
py1 = data['Track1 PY(MeV) '].to_numpy()
pz1 = data['Track1 PZ(MeV) '].to_numpy()
px2 = data['Track2 PX(MeV) '].to_numpy()
py2 = data['Track2 PY(MeV) '].to_numpy()
pz2 = data['Track2 PZ(MeV) '].to_numpy()

# %%
N_phi = my.luminosity * my.sigma_ee_phi
N_KLKS = N_phi * my.BR_phi_KK
print(f"Number of produced KL/KS pairs = {int(N_KLKS)}")

N_KL_CP = N_KLKS * my.BR_KL_2pi
print(f"Expected CP violating KL = {int(N_KL_CP)}")

print(f"BR = {N_KL_CP/N_KLKS}")

N_KL_CP_measured = N_KL_CP * my.acceptance * my.epsL
print(f"\nDetected CP violating KL = {int(N_KL_CP_measured)}")

N_KS_measured = N_KLKS * my.BR_KS_2pi * my.epsS
print(f"Detected KS = {int(N_KS_measured)}")

print(f"\nNumber of events in data : {len(np.where(vtx == 1)[0])}")
# Out:
# Number of produced KL/KS pairs = 204000
# Expected CP violating KL = 408
# BR = 0.002
#
# Detected CP violating KL = 51
# Detected KS = 98532
#
# Number of events in data : 200743

# %%
# Define some useful quantities
radius = np.sqrt(x*x + y*y + z*z)

mass_array = np.repeat(my.m_pi, len(data))
E1 = my.getE(mass_array, px1, py1, pz1)
E2 = my.getE(mass_array, px2, py2, pz2)
inv_mass = my.invmass(E1+E2, px1+px2, py1+py2, pz1+pz2)

p_array = np.repeat(my.p_K0, len(data))
p_tot = my.norm(px1+px2, py1+py2, pz1+pz2)

mass_K_array = np.repeat(my.m_K0, len(data))
pKx, pKy, pKz = my.getComponents(p_array, x, y, z)
E_K = my.getE(mass_K_array, pKx, pKy, pKz)

delta_px = pKx - px1 - px2
delta_py = pKy - py1 - py2
delta_pz = pKz - pz1 - pz2

missing_p = my.norm(pKx-px1-px2, pKy-py1-py2, pKz-pz1-pz2)
M2 = (E_K - E1 -E2)**2 - missing_p**2

angle_K_pi = my.angle_of_vectors(pKx, pKy, pKz, px1+px2, py1+py2, pz1+pz2)

# %%
# Define cuts

cut_r = (radius >= 10)
cut_r_inv = np.invert(cut_r)
cut_FV = (z > -my.zlim) & (z < my.zlim) & (np.sqrt(x*x+y*y) > my.xmin) & (np.sqrt(x*x+y*y) < my.xmax)
cut_m = (inv_mass > my.m_K0 - 8) & (inv_mass < my.m_K0 + 8)
cut_p = (p_tot > my.p_K0 - 20) & (p_tot < my.p_K0 + 20)

cut_M2 = (M2 > -100) & (M2 < 100)
cut_pxpypz = (delta_px > -15) & (delta_px < 15) & (delta_py > -15) & (delta_py < 15) & (delta_pz > -15) & (delta_pz < 15)
cut_angle = (0.990 <= np.cos(np.radians(angle_K_pi))) & (np.cos(np.radians(angle_K_pi)) <= 1)

# %%
# Out:
# (130.6, 90.6)

# %%
nbins = 100
lims = (0, 300)

plt.hist(radius, bins = nbins, range = lims, histtype = 'step')

# plt.hist([radius[cut_FV], radius[cut_FV == False]], 
#          bins = nbins, range = lims, histtype = 'step',
#          label = ['cut_FV','not FV'], stacked = True)

plt.hist([radius[cut_r], radius[cut_r == False]], 
         bins = nbins, range = lims, histtype = 'step',
         label = ['radius > 10cm','radius < 10cm'], stacked = True)

# plt.ylim(0, 15000)
plt.xlabel('Radius [cm]')
plt.ylabel('Counts')
plt.legend();
plt.savefig('radius.jpg', dpi = 300)

# %%
lims = (250, 800)

nbins = 100

plt.hist([inv_mass[cut_r], inv_mass[(cut_r) == False]], 
         histtype = 'step', bins = nbins, range = lims, 
         label = ['r > 10cm', 'r < 10 cm'], stacked = True)

plt.vlines(my.m_K0, 0, 50000, 'r', linestyle = 'dashed', label = 'K0 mass', alpha = 0.5)
plt.xlim(lims)
plt.xlabel('Invariant Mass of two tracks')
plt.ylabel('Counts')
plt.legend();
plt.savefig('Inv_mass.jpg', dpi = 300)

# %%
bins = 100
lims = (0,500)

plt.hist([p_tot[cut_r], p_tot[(cut_r) == False]], 
         histtype = 'step', bins = nbins, range = lims, 
         label = ['r > 10cm', 'r < 10 cm'], stacked = True)

plt.vlines(my.p_K0, 0, 30000, 'r', linestyle = 'dashed', label = 'pK0', alpha = 0.5)
plt.xlabel('Total momentum of two tracks')
plt.ylabel('Counts')
plt.legend();
plt.savefig('momentum.jpg', dpi = 300)

# %%
plt.figure(figsize = (12,4))

bins = 100
lims = (-500,500)

plt.subplot(131)


plt.hist(delta_px, histtype = 'step', bins = bins, range = lims,label = 'delta px')
plt.hist(delta_px[cut_r_inv & cut_m], histtype = 'step', bins = bins, range = lims, label = 'r<10cm & good \ninv. mass')
plt.legend()

plt.subplot(132)


plt.hist(delta_py, histtype = 'step', bins = bins, range = lims,label = 'delta py')
plt.hist(delta_py[cut_r_inv & cut_m], histtype = 'step', bins = bins, range = lims, label = 'r<10cm & good \ninv. mass')
plt.legend()

plt.subplot(133)

plt.hist(delta_pz, histtype = 'step', bins = bins, range = lims, label = 'delta pz')
plt.hist(delta_pz[cut_r_inv & cut_m], histtype = 'step', bins = bins, range = lims, label = 'r<10cm & good \ninv. mass')

plt.legend()

plt.tight_layout();

# %%
lims = (-150000,150000)
bins = 100
plt.ticklabel_format(axis='x', style='sci', scilimits=(0,3), useMathText = True)


plt.hist([M2[cut_r], M2[(cut_r) == False]], 
         histtype = 'step', bins = nbins, range = lims, 
         label = ['r > 10cm', 'r < 10 cm'], stacked = True)

plt.vlines(my.m_pi**2, 0, 20000, 'r', linestyle = 'dashed', label = 'pi mass', alpha = 0.5)
plt.legend()
plt.xlim(lims);

# %%
theta = my.getTheta(x,y,z)
bins = 100
lims = (-1,1)

plt.hist([np.cos(theta[cut_r]), np.cos(theta[(cut_r) == False])], 
         histtype = 'step', bins = nbins, range = lims, 
         label = ['r > 10cm', 'r < 10 cm'], stacked = True);

plt.xlabel('cos[Theta]')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
phi = my.getPhi(x,y,z)

bins = 50

plt.hist([phi[cut_r], phi[(cut_r) == False]], 
         histtype = 'step', bins = nbins, range = lims, 
         label = ['r > 10cm', 'r < 10 cm'], stacked = True);

plt.xlabel('Phi')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
bins = 100
lims = (-1,1)

plt.hist([np.cos(np.radians(angle_K_pi[cut_r])), np.cos(np.radians(angle_K_pi[(cut_r) == False]))], 
         histtype = 'step', bins = bins, range = lims,
         label = ['r > 10cm', 'r < 10 cm'], stacked = True);

# plt.hist(np.cos(np.radians(angle_K_pi[(cut_r==False) & cut_m ])), 
#          histtype = 'step', bins = bins, range = lims,
#          label =  'r < 10 cm')

# plt.hist(np.cos(np.radians(angle_K_pi[cut_r & cut_m])), 
#          histtype = 'step', bins = bins, range = lims,
#          label =  'r>10cm')

plt.xlabel('Angle between kaon momentum and the sum of tracks momenta')
plt.ylabel('Counts')
plt.xlim(lims)
plt.legend()
plt.savefig('Angle.jpg', dpi = 300)
plt.show()

# %% [markdown]
# # Event Display

# %%
# 0 for KS -> 2pi event
# 259681:259683 for KS-KL decay near IP
# 259315: 259317
# 17233 KL->2pi event
# 54026:54028 KL->2pi KS->2pi event

sliced = data.iloc[54026:54028]
sliced
# Out:
#            #  # vtx with two tracks of opposite curvature    XV (cm)
# 54026  54026                                            1  73.088081  \
# 54027  54027                                            2   0.114014
#
#            YV(cm)    ZV(cm)  Track1 PX(MeV)   Track1 PY(MeV)
# 54026 -126.094719 -1.711717      -139.449814       -62.207191  \
# 54027   -0.021364  1.158172      -164.974686       -53.081799
#
#        Track1 PZ(MeV)   Track2 PX(MeV)   Track2 PY(MeV)   Track2 PZ(MeV)
# 54026       119.640877       194.446457       -30.986448      -124.246132
# 54027      -125.345108        94.644524       147.049469       125.921745

# %%
N = sliced['#'].values

from matplotlib.patches import Rectangle

event = N
fig, ax = plt.subplots(1, 2,figsize=(10, 5))

j = 70
for i in event:
    col = (np.random.random(), np.random.random(), np.random.random())
    
    V = [x[i],y[i]]
    origin = [0,0] # origin point

    ax[0].quiver(*origin, V[0], V[1], color = col, angles='xy', scale_units='xy', scale=1,
               headlength = 2, headaxislength = 2, width = 0.005, ls = '--')
    
    track1 = [px1[i],py1[i]]
    ax[0].quiver(*V, track1[0], track1[1], color=col, angles='xy', scale_units='xy', 
               scale=1, headlength = 2, headaxislength = 2, width = 0.003)
    
    track2 = [px2[i],py2[i]]
    ax[0].quiver(*V, track2[0], track2[1], color=col, angles='xy', scale_units='xy', 
               scale=1, headlength = 2, headaxislength = 2, width = 0.003)

    ax[0].add_patch(Rectangle((-150, -150), 300, 300,
             edgecolor = 'cyan',
             facecolor = 'blue',
             fill=False,
             lw=1))
    
    V = [z[i],y[i]]
    origin = [0,0] # origin point

    ax[1].quiver(*origin, V[0], V[1], color = col , angles='xy', scale_units='xy', scale=1,
               headlength = 2, headaxislength = 2, width = 0.005, ls = '--')
    
    track1 = [pz1[i],py1[i]]
    ax[1].quiver(*V, track1[0], track1[1], color=col, angles='xy', scale_units='xy', 
               scale=1, headlength = 2, headaxislength = 2, width = 0.003)
    track2 = [pz2[i],py2[i]]
    ax[1].quiver(*V, track2[0], track2[1], color=col, angles='xy', scale_units='xy', 
               scale=1, headlength = 2, headaxislength = 2, width = 0.003)
    
    ax[1].add_patch(Rectangle((-120, -150), 240, 300,
         edgecolor = 'cyan',
         facecolor = 'blue',
         fill=False,
         lw=1))
    j = 1
    

ax[0].set_xlim([-200, 200])
ax[0].set_xlabel('X')
ax[0].set_ylim([-200, 200])
ax[0].set_ylabel('Y')
ax[1].set_xlim([-200, 200])
ax[1].set_ylim([-200, 200])
ax[1].set_xlabel('Z')
ax[1].set_ylabel('Y')
ax[0].set_facecolor('black')
ax[1].set_facecolor('black')

plt.savefig('2pi.jpg', dpi = 300)

# %% [markdown]
# # Data Processing

# %%
vtx1 = vtx                                                                   # Auxiliary variable to eventually slice data

events = np.where(vtx1 == 1)[0]
ext_events = np.append(events,len(vtx1))                                     # extend array to avoid problems in for loop


tol = np.pi/10



KS_2pi = 0
KL_CP = 0

kl_cp_index = []
ks_2pi_index = []


for i, eve in enumerate(events):                                             # Loop through events
    
    event_length = ext_events[i+1]-ext_events[i]
    print(f'-> Event {i} Index {eve} Length {event_length}')
    
    if event_length == 1:
        if cut_FV[eve] & cut_m[eve] & cut_p[eve] & cut_angle[eve]:           # CP violating KL detected in FV
            KL_CP += 1
            kl_cp_index.append(eve)
            print('\tFound KL->2pi')
        elif cut_r_inv[eve] & cut_m[eve] & cut_p[eve]:                       # KS near IP so a KL must be somewhere                                         
                KS_2pi += 1
                ks_2pi_index.append(eve)
                print('\tKS->2pi')
    
    
    elif event_length > 1:                                                   # Case with more than 1 vertex
        
        BTB = 0
        
        for j in range(0, event_length):
            for k in range(j+1, event_length):
                
                if (-tol + np.pi < (theta[j+eve] + theta[k+eve]) < tol + np.pi):
                    if (np.pi-tol < abs(phi[k+eve] - phi[j+eve]) < np.pi+tol):
                        if (radius[k+eve] <= radius[j+eve]):
                            
                            BTB += 1
                            print(f'\t{k+eve} is a KS, {j+eve} is a KL')
                            
                            if cut_r_inv[k+eve] & cut_m[k+eve] & cut_p[k+eve]:
                                KS_2pi += 1
                                ks_2pi_index.append(k+eve)
                                print('\tKS -> 2pi')

                            if cut_FV[j+eve] & cut_m[j+eve] & cut_p[j+eve] & cut_angle[j+eve]:
                                KL_CP += 1
                                kl_cp_index.append(j+eve)
                                print(f'\tKL -> 2pi')
                                
                        elif (radius[k+eve] > radius[j+eve]):

                            BTB += 1
                            print(f'\t{j+eve} is a KS, {k+eve} is a KL')

                            if cut_r_inv[j+eve] & cut_m[j+eve] & cut_p[j+eve]:
                                KS_2pi += 1
                                ks_2pi_index.append(j+eve)
                                print('\tKS -> 2pi')
                            
                            if cut_FV[k+eve] & cut_m[k+eve] & cut_p[k+eve] & cut_angle[k+eve]:
                                kl_cp_index.append(k+eve)
                                KL_CP += 1
                                print(f'\tKL -> 2pi')
                else:
                    print(f'\tNo Kaon to Tag {j+eve}, {k+eve}')
        
        
        if BTB == 0:
            for j in range(0, event_length):
                if cut_r_inv[j+eve] & cut_m[j+eve] & cut_p[j+eve]:
                    KS_2pi += 1
                    ks_2pi_index.append(j+eve)
                    print('\tKS -> 2pi')
                    
                elif cut_FV[j+eve] & cut_m[j+eve] & cut_p[j+eve] & cut_angle[j+eve]: 
                    KL_CP += 1
                    kl_cp_index.append(j+eve)
                    print('\tFound KL->2pi')
# Out:
# -> Event 0 Index 0 Length 1
# 	KS->2pi
# -> Event 1 Index 1 Length 1
# 	KS->2pi
# -> Event 2 Index 2 Length 1
# -> Event 3 Index 3 Length 1
# 	KS->2pi
# -> Event 4 Index 4 Length 1
# -> Event 5 Index 5 Length 1
# -> Event 6 Index 6 Length 4
# 	No Kaon to Tag 6, 8
# 	6 is a KS, 9 is a KL
# 	No Kaon to Tag 7, 9
# 	No Kaon to Tag 8, 9
# -> Event 7 Index 10 Length 1
# 	KS->2pi
# -> Event 8 Index 11 Length 1
# 	KS->2pi
# -> Event 9 Index 12 Length 2
# 	12 is a KS, 13 is a KL
# 	KS -> 2pi
# -> Event 10 Index 14 Length 1
# 	KS->2pi
# -> Event 11 Index 15 Length 3
# 	No Kaon to Tag 15, 16
# 	No Kaon to Tag 15, 17
# 	No Kaon to Tag 16, 17
# -> Event 12 Index 18 Length 1
# -> Event 13 Index 19 Length 2
# 	No Kaon to Tag 19, 20
# 	KS -> 2pi
# -> Event 14 Index 21 Length 1
# -> Event 15 Index 22 Length 2
# 	No Kaon to Tag 22, 23
# -> Event 16 Index 24 Length 1
# -> Event 17 Index 25 Length 1
# -> Event 18 Index 26 Length 1
# 	KS->2pi
# -> Event 19 Index 27 Length 1
# -> Event 20 Index 28 Length 2
# -> Event 21 Index 30 Length 1
# 	KS->2pi
# -> Event 22 Index 31 Length 1
# 	KS->2pi
# -> Event 23 Index 32 Length 1
# -> Event 24 Index 33 Length 1
# -> Event 25 Index 34 Length 3
# 	No Kaon to Tag 34, 35
# 	No Kaon to Tag 35, 36
# -> Event 26 Index 37 Length 1
# -> Event 27 Index 38 Length 1
# -> Event 28 Index 39 Length 1
# -> Event 29 Index 40 Length 2
# 	No Kaon to Tag 40, 41
# 	KS -> 2pi
# -> Event 30 Index 42 Length 3
# 	No Kaon to Tag 42, 43
# 	No Kaon to Tag 43, 44
# -> Event 31 Index 45 Length 2
# -> Event 32 Index 47 Length 1
# 	KS->2pi
# -> Event 33 Index 48 Length 2
# -> Event 34 Index 50 Length 2
# 	No Kaon to Tag 50, 51
# 	KS -> 2pi
# -> Event 35 Index 52 Length 2
# 	No Kaon to Tag 52, 53
# 	KS -> 2pi
# -> Event 36 Index 54 Length 1
# -> Event 37 Index 55 Length 3
# 	No Kaon to Tag 55, 56
# 	No Kaon to Tag 56, 57
# -> Event 38 Index 58 Length 1
# 	KS->2pi
# -> Event 39 Index 59 Length 2
# 	No Kaon to Tag 59, 60
# -> Event 40 Index 61 Length 1
# -> Event 41 Index 62 Length 1
# 	KS->2pi
# -> Event 42 Index 63 Length 1
# 	KS->2pi
# -> Event 43 Index 64 Length 1
# -> Event 44 Index 65 Length 1
# -> Event 45 Index 66 Length 1
# 	KS->2pi
# -> Event 46 Index 67 Length 1
# 	KS->2pi
# -> Event 47 Index 68 Length 1
# -> Event 48 Index 69 Length 3
# 	No Kaon to Tag 69, 70
# 	No Kaon to Tag 69, 71
# 	No Kaon to Tag 70, 71
# -> Event 49 Index 72 Length 5
# 	No Kaon to Tag 72, 73
# 	No Kaon to Tag 72, 75
# 	No Kaon to Tag 72, 76
# 	No Kaon to Tag 73, 75
# 	No Kaon to Tag 73, 76
# 	No Kaon to Tag 74, 76
# 	No Kaon to Tag 75, 76
# -> Event 50 Index 77 Length 1
# 	KS->2pi
# -> Event 51 Index 78 Length 3
# 	No Kaon to Tag 78, 79
# 	No Kaon to Tag 78, 80
# -> Event 52 Index 81 Length 1
# -> Event 53 Index 82 Length 1
# -> Event 54 Index 83 Length 1
# -> Event 55 Index 84 Length 1
# -> Event 56 Index 85 Length 1
# -> Event 57 Index 86 Length 2
# 	No Kaon to Tag 86, 87
# -> Event 58 Index 88 Length 2
# -> Event 59 Index 90 Length 2
# 	No Kaon to Tag 90, 91
# -> Event 60 Index 92 Length 5
# 	No Kaon to Tag 92, 94
# 	No Kaon to Tag 92, 95
# 	No Kaon to Tag 93, 94
# 	No Kaon to Tag 93, 95
# 	No Kaon to Tag 93, 96
# 	No Kaon to Tag 94, 96
# -> Event 61 Index 97 Length 1
# -> Event 62 Index 98 Length 2
# -> Event 63 Index 100 Length 4
# 	No Kaon to Tag 100, 102
# 	No Kaon to Tag 100, 103
# 	No Kaon to Tag 101, 102
# 	No Kaon to Tag 101, 103
# 	No Kaon to Tag 102, 103
# -> Event 64 Index 104 Length 6
# 	No Kaon to Tag 104, 105
# 	No Kaon to Tag 104, 107
# 	No Kaon to Tag 104, 108
# 	No Kaon to Tag 104, 109
# 	No Kaon to Tag 105, 106
# 	No Kaon to Tag 105, 108
# 	No Kaon to Tag 105, 109
# 	No Kaon to Tag 106, 107
# 	No Kaon to Tag 106, 108
# 	No Kaon to Tag 107, 109
# 	No Kaon to Tag 108, 109
# -> Event 65 Index 110 Length 2
# 	No Kaon to Tag 110, 111
# -> Event 66 Index 112 Length 1
# -> Event 67 Index 113 Length 1
# 	KS->2pi
# -> Event 68 Index 114 Length 2
# 	No Kaon to Tag 114, 115
# 	KS -> 2pi
# -> Event 69 Index 116 Length 1
# 	KS->2pi
# -> Event 70 Index 117 Length 1
# -> Event 71 Index 118 Length 1
# 	KS->2pi
# -> Event 72 Index 119 Length 1
# 	KS->2pi
# -> Event 73 Index 120 Length 1
# 	KS->2pi
# -> Event 74 Index 121 Length 4
# 	No Kaon to Tag 121, 122
# 	No Kaon to Tag 121, 124
# 	No Kaon to Tag 122, 123
# 	No Kaon to Tag 123, 124
# -> Event 75 Index 125 Length 3
# 	No Kaon to Tag 125, 126
# 	No Kaon to Tag 125, 127
# 	No Kaon to Tag 126, 127
# -> Event 76 Index 128 Length 1
# 	KS->2pi
# -> Event 77 Index 129 Length 4
# 	No Kaon to Tag 129, 130
# 	No Kaon to Tag 129, 131
# 	No Kaon to Tag 129, 132
# 	No Kaon to Tag 130, 132
# 	KS -> 2pi
# -> Event 78 Index 133 Length 2
# 	No Kaon to Tag 133, 134
# 	KS -> 2pi
# -> Event 79 Index 135 Length 1
# -> Event 80 Index 136 Length 3
# 	No Kaon to Tag 136, 137
# 	No Kaon to Tag 136, 138
# -> Event 81 Index 139 Length 2
# 	No Kaon to Tag 139, 140
# -> Event 82 Index 141 Length 3
# 	No Kaon to Tag 141, 142
# 	No Kaon to Tag 141, 143
# 	No Kaon to Tag 142, 143
# -> Event 83 Index 144 Length 1
# -> Event 84 Index 145 Length 2
# 	No Kaon to Tag 145, 146
# -> Event 85 Index 147 Length 1
# -> Event 86 Index 148 Length 1
# 	KS->2pi
# -> Event 87 Index 149 Length 1
# 	KS->2pi
# -> Event 88 Index 150 Length 1
# 	KS->2pi
# -> Event 89 Index 151 Length 2
# 	No Kaon to Tag 151, 152
# -> Event 90 Index 153 Length 1
# -> Event 91 Index 154 Length 2
# 	No Kaon to Tag 154, 155
# -> Event 92 Index 156 Length 1
# 	KS->2pi
# -> Event 93 Index 157 Length 1
# 	KS->2pi
# -> Event 94 Index 158 Length 1
# -> Event 95 Index 159 Length 1
# 	KS->2pi
# -> Event 96 Index 160 Length 1
# 	KS->2pi
# -> Event 97 Index 161 Length 1
# 	KS->2pi
# -> Event 98 Index 162 Length 2
# 	No Kaon to Tag 162, 163
# 	KS -> 2pi
# -> Event 99 Index 164 Length 1
# 	KS->2pi
# -> Event 100 Index 165 Length 1
# 	KS->2pi
# -> Event 101 Index 166 Length 2
# 	No Kaon to Tag 166, 167
# 	KS -> 2pi
# -> Event 102 Index 168 Length 4
# 	No Kaon to Tag 168, 169
# 	No Kaon to Tag 168, 170
# 	No Kaon to Tag 169, 170
# -> Event 103 Index 172 Length 1
# 	KS->2pi
# -> Event 104 Index 173 Length 1
# 	KS->2pi
# -> Event 105 Index 174 Length 1
# -> Event 106 Index 175 Length 1
# 	KS->2pi
# -> Event 107 Index 176 Length 1
# -> Event 108 Index 177 Length 2
# 	No Kaon to Tag 177, 178
# 	KS -> 2pi
# -> Event 109 Index 179 Length 1
# 	KS->2pi
# -> Event 110 Index 180 Length 1
# -> Event 111 Index 181 Length 1
# 	KS->2pi
# -> Event 112 Index 182 Length 2
# -> Event 113 Index 184 Length 1
# -> Event 114 Index 185 Length 1
# -> Event 115 Index 186 Length 1
# 	KS->2pi
# -> Event 116 Index 187 Length 1
# 	KS->2pi
# -> Event 117 Index 188 Length 1
# -> Event 118 Index 189 Length 1
# -> Event 119 Index 190 Length 1
# -> Event 120 Index 191 Length 1
# 	KS->2pi
# -> Event 121 Index 192 Length 3
# 	No Kaon to Tag 192, 193
# 	No Kaon to Tag 193, 194
# 	KS -> 2pi
# -> Event 122 Index 195 Length 1
# 	KS->2pi
# -> Event 123 Index 196 Length 1
# -> Event 124 Index 197 Length 1
# 	KS->2pi
# -> Event 125 Index 198 Length 3
# 	No Kaon to Tag 198, 199
# 	No Kaon to Tag 199, 200
# 	KS -> 2pi
# -> Event 126 Index 201 Length 2
# 	No Kaon to Tag 201, 202
# 	KS -> 2pi
# -> Event 127 Index 203 Length 1
# -> Event 128 Index 204 Length 3
# 	No Kaon to Tag 204, 205
# 	No Kaon to Tag 204, 206
# 	No Kaon to Tag 205, 206
# -> Event 129 Index 207 Length 1
# -> Event 130 Index 208 Length 2
# -> Event 131 Index 210 Length 1
# 	KS->2pi
# -> Event 132 Index 211 Length 1
# 	KS->2pi
# -> Event 133 Index 212 Length 1
# 	KS->2pi
# -> Event 134 Index 213 Length 1
# -> Event 135 Index 214 Length 1
# -> Event 136 Index 215 Length 1
# -> Event 137 Index 216 Length 1
# -> Event 138 Index 217 Length 1
# 	KS->2pi
# -> Event 139 Index 218 Length 2
# 	KS -> 2pi
# -> Event 140 Index 220 Length 2
# 	No Kaon to Tag 220, 221
# 	KS -> 2pi
# -> Event 141 Index 222 Length 1
# 	KS->2pi
# -> Event 142 Index 223 Length 1
# -> Event 143 Index 224 Length 3
# 	No Kaon to Tag 225, 226
# -> Event 144 Index 227 Length 1
# -> Event 145 Index 228 Length 3
# 	No Kaon to Tag 229, 230
# -> Event 146 Index 231 Length 1
# 	KS->2pi
# -> Event 147 Index 232 Length 1
# -> Event 148 Index 233 Length 1
# 	KS->2pi
# -> Event 149 Index 234 Length 1
# -> Event 150 Index 235 Length 1
# 	KS->2pi
# -> Event 151 Index 236 Length 1
# -> Event 152 Index 237 Length 1
# -> Event 153 Index 238 Length 1
# 	KS->2pi
# -> Event 154 Index 239 Length 1
# -> Event 155 Index 240 Length 1
# 	KS->2pi
# -> Event 156 Index 241 Length 1
# -> Event 157 Index 242 Length 1
# 	KS->2pi
# -> Event 158 Index 243 Length 2
# 	No Kaon to Tag 243, 244
# 	KS -> 2pi
# -> Event 159 Index 245 Length 1
# -> Event 160 Index 246 Length 1
# 	KS->2pi
# -> Event 161 Index 247 Length 1
# -> Event 162 Index 248 Length 1
# -> Event 163 Index 249 Length 1
# 	KS->2pi
# -> Event 164 Index 250 Length 1
# -> Event 165 Index 251 Length 1
# 	KS->2pi
# -> Event 166 Index 252 Length 1
# -> Event 167 Index 253 Length 1
# 	KS->2pi
# -> Event 168 Index 254 Length 1
# -> Event 169 Index 255 Length 3
# 	No Kaon to Tag 255, 256
# 	No Kaon to Tag 255, 257
# 	No Kaon to Tag 256, 257
# 	KS -> 2pi
# -> Event 170 Index 258 Length 3
# 	No Kaon to Tag 258, 259
# 	No Kaon to Tag 259, 260
# -> Event 171 Index 261 Length 2
# 	No Kaon to Tag 261, 262
# 	KS -> 2pi
# -> Event 172 Index 263 Length 1
# 	KS->2pi
# -> Event 173 Index 264 Length 2
# 	264 is a KS, 265 is a KL
# 	KS -> 2pi
# -> Event 174 Index 266 Length 1
# -> Event 175 Index 267 Length 1
# 	KS->2pi
# -> Event 176 Index 268 Length 2
# 	No Kaon to Tag 268, 269
# -> Event 177 Index 270 Length 1
# 	KS->2pi
# -> Event 178 Index 271 Length 1
# -> Event 179 Index 272 Length 2
# 	No Kaon to Tag 272, 273
# 	KS -> 2pi
# -> Event 180 Index 274 Length 2
# 	No Kaon to Tag 274, 275
# 	KS -> 2pi
# -> Event 181 Index 276 Length 1
# 	KS->2pi
# -> Event 182 Index 277 Length 1
# 	KS->2pi
# -> Event 183 Index 278 Length 1
# -> Event 184 Index 279 Length 3
# 	No Kaon to Tag 279, 280
# -> Event 185 Index 282 Length 1
# 	KS->2pi
# -> Event 186 Index 283 Length 1
# 	KS->2pi
# -> Event 187 Index 284 Length 1
# 	KS->2pi
# -> Event 188 Index 285 Length 3
# 	No Kaon to Tag 285, 286
# 	No Kaon to Tag 285, 287
# 	No Kaon to Tag 286, 287
# 	KS -> 2pi
# -> Event 189 Index 288 Length 1
# 	KS->2pi
# -> Event 190 Index 289 Length 2
# 	No Kaon to Tag 289, 290
# -> Event 191 Index 291 Length 1
# 	KS->2pi
# -> Event 192 Index 292 Length 2
# -> Event 193 Index 294 Length 1
# 	KS->2pi
# -> Event 194 Index 295 Length 1
# 	KS->2pi
# -> Event 195 Index 296 Length 1
# -> Event 196 Index 297 Length 1
# 	KS->2pi
# -> Event 197 Index 298 Length 4
# 	No Kaon to Tag 298, 299
# 	No Kaon to Tag 298, 300
# 	No Kaon to Tag 298, 301
# 	300 is a KS, 299 is a KL
# 	No Kaon to Tag 299, 301
# 	300 is a KS, 301 is a KL
# -> Event 198 Index 302 Length 3
# 	No Kaon to Tag 302, 303
# 	No Kaon to Tag 302, 304
# 	No Kaon to Tag 303, 304
# 	KS -> 2pi
# -> Event 199 Index 305 Length 2
# 	305 is a KS, 306 is a KL
# 	KS -> 2pi
# -> Event 200 Index 307 Length 1
# 	KS->2pi
# -> Event 201 Index 308 Length 3
# 	No Kaon to Tag 308, 309
# 	No Kaon to Tag 308, 310
# 	No Kaon to Tag 309, 310
# 	KS -> 2pi
# -> Event 202 Index 311 Length 3
# 	No Kaon to Tag 311, 312
# -> Event 203 Index 314 Length 1
# 	KS->2pi
# -> Event 204 Index 315 Length 2
# -> Event 205 Index 317 Length 1
# 	KS->2pi
# -> Event 206 Index 318 Length 1
# 	KS->2pi
# -> Event 207 Index 319 Length 1
# 	KS->2pi
# -> Event 208 Index 320 Length 1
# 	KS->2pi
# -> Event 209 Index 321 Length 2
# 	No Kaon to Tag 321, 322
# -> Event 210 Index 323 Length 1
# -> Event 211 Index 324 Length 2
# 	No Kaon to Tag 324, 325
# 	KS -> 2pi
# -> Event 212 Index 326 Length 3
# 	No Kaon to Tag 326, 327
# 	No Kaon to Tag 326, 328
# 	No Kaon to Tag 327, 328
# 	KS -> 2pi
# -> Event 213 Index 329 Length 1
# -> Event 214 Index 330 Length 4
# 	No Kaon to Tag 330, 332
# 	No Kaon to Tag 330, 333
# 	No Kaon to Tag 331, 332
# -> Event 215 Index 334 Length 2
# 	No Kaon to Tag 334, 335
# 	KS -> 2pi
# -> Event 216 Index 336 Length 1
# 	KS->2pi
# -> Event 217 Index 337 Length 1
# -> Event 218 Index 338 Length 2
# 	No Kaon to Tag 338, 339
# -> Event 219 Index 340 Length 3
# 	No Kaon to Tag 340, 341
# 	No Kaon to Tag 341, 342
# -> Event 220 Index 343 Length 2
# -> Event 221 Index 345 Length 1
# -> Event 222 Index 346 Length 1
# 	KS->2pi
# -> Event 223 Index 347 Length 1
# 	KS->2pi
# -> Event 224 Index 348 Length 3
# 	No Kaon to Tag 348, 349
# 	No Kaon to Tag 349, 350
# -> Event 225 Index 351 Length 1
# 	KS->2pi
# -> Event 226 Index 352 Length 1
# -> Event 227 Index 353 Length 1
# -> Event 228 Index 354 Length 2
# 	No Kaon to Tag 354, 355
# 	KS -> 2pi
# -> Event 229 Index 356 Length 1
# -> Event 230 Index 357 Length 1
# 	KS->2pi
# -> Event 231 Index 358 Length 1
# -> Event 232 Index 359 Length 1
# -> Event 233 Index 360 Length 1
# -> Event 234 Index 361 Length 1
# 	KS->2pi
# -> Event 235 Index 362 Length 2
# 	No Kaon to Tag 362, 363
# 	KS -> 2pi
# -> Event 236 Index 364 Length 1
# -> Event 237 Index 365 Length 3
# 	No Kaon to Tag 365, 366
# 	No Kaon to Tag 366, 367
# -> Event 238 Index 368 Length 1
# 	KS->2pi
# -> Event 239 Index 369 Length 1
# -> Event 240 Index 370 Length 2
# 	No Kaon to Tag 370, 371
# -> Event 241 Index 372 Length 2
# 	No Kaon to Tag 372, 373
# -> Event 242 Index 374 Length 1
# 	KS->2pi
# -> Event 243 Index 375 Length 4
# 	No Kaon to Tag 375, 377
# 	No Kaon to Tag 375, 378
# 	No Kaon to Tag 376, 378
# 	No Kaon to Tag 377, 378
# -> Event 244 Index 379 Length 1
# -> Event 245 Index 380 Length 2
# 	No Kaon to Tag 380, 381
# 	KS -> 2pi
# -> Event 246 Index 382 Length 1
# 	KS->2pi
# -> Event 247 Index 383 Length 1
# -> Event 248 Index 384 Length 3
# 	No Kaon to Tag 384, 386
# 	No Kaon to Tag 385, 386
# 	KS -> 2pi
# -> Event 249 Index 387 Length 2
# 	No Kaon to Tag 387, 388
# -> Event 250 Index 389 Length 1
# 	KS->2pi
# -> Event 251 Index 390 Length 5
# 	No Kaon to Tag 390, 392
# 	No Kaon to Tag 390, 393
# 	No Kaon to Tag 390, 394
# 	No Kaon to Tag 391, 392
# 	No Kaon to Tag 391, 394
# 	No Kaon to Tag 392, 393
# 	No Kaon to Tag 392, 394
# 	No Kaon to Tag 393, 394
# -> Event 252 Index 395 Length 1
# 	KS->2pi
# -> Event 253 Index 396 Length 1
# -> Event 254 Index 397 Length 1
# -> Event 255 Index 398 Length 1
# 	KS->2pi
# -> Event 256 Index 399 Length 1
# 	KS->2pi
# -> Event 257 Index 400 Length 1
# -> Event 258 Index 401 Length 1
# -> Event 259 Index 402 Length 1
# -> Event 260 Index 403 Length 4
# 	No Kaon to Tag 403, 404
# 	No Kaon to Tag 403, 405
# 	No Kaon to Tag 404, 405
# 	No Kaon to Tag 404, 406
# 	No Kaon to Tag 405, 406
# -> Event 261 Index 407 Length 1
# 	KS->2pi
# -> Event 262 Index 408 Length 1
# 	KS->2pi
# -> Event 263 Index 409 Length 6
# 	No Kaon to Tag 409, 410
# 	No Kaon to Tag 409, 411
# 	No Kaon to Tag 409, 412
# 	No Kaon to Tag 409, 413
# 	No Kaon to Tag 409, 414
# 	No Kaon to Tag 410, 411
# 	No Kaon to Tag 410, 412
# 	No Kaon to Tag 410, 413
# 	No Kaon to Tag 410, 414
# 	No Kaon to Tag 411, 413
# 	No Kaon to Tag 412, 413
# 	No Kaon to Tag 412, 414
# 	No Kaon to Tag 413, 414
# 	KS -> 2pi
# -> Event 264 Index 415 Length 1
# -> Event 265 Index 416 Length 1
# 	KS->2pi
# -> Event 266 Index 417 Length 2
# 	No Kaon to Tag 417, 418
# -> Event 267 Index 419 Length 2
# 	No Kaon to Tag 419, 420
# -> Event 268 Index 421 Length 1
# -> Event 269 Index 422 Length 5
# 	No Kaon to Tag 422, 424
# 	No Kaon to Tag 422, 425
# 	No Kaon to Tag 423, 424
# 	No Kaon to Tag 423, 425
# 	No Kaon to Tag 423, 426
# 	No Kaon to Tag 424, 425
# 	No Kaon to Tag 424, 426
# 	No Kaon to Tag 425, 426
# -> Event 270 Index 427 Length 2
# 	No Kaon to Tag 427, 428
# -> Event 271 Index 429 Length 4
# 	No Kaon to Tag 429, 430
# 	No Kaon to Tag 429, 431
# 	No Kaon to Tag 429, 432
# 	No Kaon to Tag 430, 431
# 	No Kaon to Tag 430, 432
# -> Event 272 Index 433 Length 2
# 	No Kaon to Tag 433, 434
# -> Event 273 Index 435 Length 4
# 	No Kaon to Tag 435, 436
# 	No Kaon to Tag 435, 437
# 	No Kaon to Tag 436, 437
# -> Event 274 Index 439 Length 1
# -> Event 275 Index 440 Length 1
# -> Event 276 Index 441 Length 1
# 	KS->2pi
# -> Event 277 Index 442 Length 2
# 	KS -> 2pi
# -> Event 278 Index 444 Length 2
# 	No Kaon to Tag 444, 445
# 	KS -> 2pi
# -> Event 279 Index 446 Length 2
# -> Event 280 Index 448 Length 1
# 	KS->2pi
# -> Event 281 Index 449 Length 1
# 	KS->2pi
# -> Event 282 Index 450 Length 2
# 	No Kaon to Tag 450, 451
# 	KS -> 2pi
# -> Event 283 Index 452 Length 2
# 	No Kaon to Tag 452, 453
# 	KS -> 2pi
# -> Event 284 Index 454 Length 3
# 	No Kaon to Tag 454, 455
# 	No Kaon to Tag 454, 456
# 	No Kaon to Tag 455, 456
# -> Event 285 Index 457 Length 1
# 	KS->2pi
# -> Event 286 Index 458 Length 1
# 	KS->2pi
# -> Event 287 Index 459 Length 1
# -> Event 288 Index 460 Length 3
# 	No Kaon to Tag 460, 461
# 	No Kaon to Tag 460, 462
# 	No Kaon to Tag 461, 462
# -> Event 289 Index 463 Length 1
# -> Event 290 Index 464 Length 1
# 	KS->2pi
# -> Event 291 Index 465 Length 1
# 	KS->2pi
# -> Event 292 Index 466 Length 1
# 	KS->2pi
# -> Event 293 Index 467 Length 1
# 	KS->2pi
# -> Event 294 Index 468 Length 2
# 	No Kaon to Tag 468, 469
# -> Event 295 Index 470 Length 2
# 	No Kaon to Tag 470, 471
# -> Event 296 Index 472 Length 1
# 	KS->2pi
# -> Event 297 Index 473 Length 1
# -> Event 298 Index 474 Length 3
# 	No Kaon to Tag 474, 475
# 	No Kaon to Tag 474, 476
# 	No Kaon to Tag 475, 476
# -> Event 299 Index 477 Length 3
# 	No Kaon to Tag 477, 478
# 	No Kaon to Tag 477, 479
# 	No Kaon to Tag 478, 479
# -> Event 300 Index 480 Length 1
# 	KS->2pi
# -> Event 301 Index 481 Length 1
# 	KS->2pi
# -> Event 302 Index 482 Length 2
# 	No Kaon to Tag 482, 483
# -> Event 303 Index 484 Length 7
# 	No Kaon to Tag 484, 485
# 	No Kaon to Tag 484, 486
# 	No Kaon to Tag 484, 487
# 	No Kaon to Tag 484, 488
# 	No Kaon to Tag 484, 489
# 	No Kaon to Tag 484, 490
# 	No Kaon to Tag 485, 486
# 	No Kaon to Tag 485, 488
# 	No Kaon to Tag 485, 489
# 	No Kaon to Tag 485, 490
# 	No Kaon to Tag 486, 487
# 	No Kaon to Tag 486, 488
# 	No Kaon to Tag 486, 489
# 	No Kaon to Tag 486, 490
# 	No Kaon to Tag 487, 488
# 	No Kaon to Tag 487, 489
# 	No Kaon to Tag 488, 489
# 	No Kaon to Tag 488, 490
# -> Event 304 Index 491 Length 1
# 	KS->2pi
# -> Event 305 Index 492 Length 1
# 	KS->2pi
# -> Event 306 Index 493 Length 1
# -> Event 307 Index 494 Length 5
# 	No Kaon to Tag 494, 495
# 	No Kaon to Tag 494, 496
# 	No Kaon to Tag 494, 498
# 	No Kaon to Tag 495, 496
# 	No Kaon to Tag 495, 497
# 	No Kaon to Tag 495, 498
# 	No Kaon to Tag 496, 497
# 	No Kaon to Tag 496, 498
# 	No Kaon to Tag 497, 498
# -> Event 308 Index 499 Length 1
# -> Event 309 Index 500 Length 4
# 	No Kaon to Tag 500, 501
# 	No Kaon to Tag 500, 503
# 	No Kaon to Tag 501, 502
# 	No Kaon to Tag 501, 503
# -> Event 310 Index 504 Length 1
# -> Event 311 Index 505 Length 1
# 	KS->2pi
# -> Event 312 Index 506 Length 5
# 	No Kaon to Tag 506, 508
# 	No Kaon to Tag 506, 509
# 	No Kaon to Tag 506, 510
# 	No Kaon to Tag 507, 508
# 	No Kaon to Tag 507, 509
# 	No Kaon to Tag 507, 510
# 	No Kaon to Tag 508, 509
# 	No Kaon to Tag 508, 510
# 	No Kaon to Tag 509, 510
# 	KS -> 2pi
# -> Event 313 Index 511 Length 1
# -> Event 314 Index 512 Length 1
# -> Event 315 Index 513 Length 2
# 	KS -> 2pi
# -> Event 316 Index 515 Length 3
# 	No Kaon to Tag 515, 517
# 	KS -> 2pi
# -> Event 317 Index 518 Length 1
# -> Event 318 Index 519 Length 1
# -> Event 319 Index 520 Length 2
# 	No Kaon to Tag 520, 521
# 	KS -> 2pi
# -> Event 320 Index 522 Length 1
# 	KS->2pi
# -> Event 321 Index 523 Length 1
# -> Event 322 Index 524 Length 1
# 	KS->2pi
# -> Event 323 Index 525 Length 1
# 	KS->2pi
# -> Event 324 Index 526 Length 1
# -> Event 325 Index 527 Length 2
# 	KS -> 2pi
# -> Event 326 Index 529 Length 1
# -> Event 327 Index 530 Length 1
# -> Event 328 Index 531 Length 1
# 	KS->2pi
# -> Event 329 Index 532 Length 3
# 	No Kaon to Tag 532, 533
# 	No Kaon to Tag 532, 534
# 	No Kaon to Tag 533, 534
# -> Event 330 Index 535 Length 3
# 	No Kaon to Tag 535, 536
# 	No Kaon to Tag 535, 537
# -> Event 331 Index 538 Length 1
# 	KS->2pi
# -> Event 332 Index 539 Length 1
# 	KS->2pi
# -> Event 333 Index 540 Length 1
# 	KS->2pi
# -> Event 334 Index 541 Length 1
# 	KS->2pi
# -> Event 335 Index 542 Length 1
# 	KS->2pi
# -> Event 336 Index 543 Length 1
# 	KS->2pi
# -> Event 337 Index 544 Length 4
# 	No Kaon to Tag 544, 545
# 	No Kaon to Tag 544, 546
# 	No Kaon to Tag 544, 547
# 	No Kaon to Tag 545, 546
# 	No Kaon to Tag 545, 547
# 	No Kaon to Tag 546, 547
# -> Event 338 Index 548 Length 2
# 	KS -> 2pi
# -> Event 339 Index 550 Length 2
# 	No Kaon to Tag 550, 551
# 	KS -> 2pi
# -> Event 340 Index 552 Length 1
# -> Event 341 Index 553 Length 1
# 	KS->2pi
# -> Event 342 Index 554 Length 2
# 	KS -> 2pi
# -> Event 343 Index 556 Length 1
# -> Event 344 Index 557 Length 2
# -> Event 345 Index 559 Length 1
# -> Event 346 Index 560 Length 3
# 	560 is a KS, 561 is a KL
# 	KS -> 2pi
# 	No Kaon to Tag 560, 562
# -> Event 347 Index 563 Length 3
# 	No Kaon to Tag 563, 564
# 	No Kaon to Tag 563, 565
# 	No Kaon to Tag 564, 565
# -> Event 348 Index 566 Length 1
# -> Event 349 Index 567 Length 1
# 	KS->2pi
# -> Event 350 Index 568 Length 1
# 	KS->2pi
# -> Event 351 Index 569 Length 3
# 	No Kaon to Tag 569, 571
# 	No Kaon to Tag 570, 571
# -> Event 352 Index 572 Length 1
# -> Event 353 Index 573 Length 1
# -> Event 354 Index 574 Length 1
# -> Event 355 Index 575 Length 1
# 	KS->2pi
# -> Event 356 Index 576 Length 1
# -> Event 357 Index 577 Length 1
# 	KS->2pi
# -> Event 358 Index 578 Length 1
# 	KS->2pi
# -> Event 359 Index 579 Length 2
# -> Event 360 Index 581 Length 2
# 	No Kaon to Tag 581, 582
# -> Event 361 Index 583 Length 1
# 	KS->2pi
# -> Event 362 Index 584 Length 3
# 	No Kaon to Tag 584, 585
# 	No Kaon to Tag 584, 586
# -> Event 363 Index 587 Length 1
# -> Event 364 Index 588 Length 1
# -> Event 365 Index 589 Length 1
# 	KS->2pi
# -> Event 366 Index 590 Length 1
# 	KS->2pi
# -> Event 367 Index 591 Length 3
# 	No Kaon to Tag 591, 592
# 	No Kaon to Tag 591, 593
# -> Event 368 Index 594 Length 1
# 	KS->2pi
# -> Event 369 Index 595 Length 1
# 	KS->2pi
# -> Event 370 Index 596 Length 1
# -> Event 371 Index 597 Length 1
# 	KS->2pi
# -> Event 372 Index 598 Length 2
# 	No Kaon to Tag 598, 599
# 	KS -> 2pi
# -> Event 373 Index 600 Length 2
# 	No Kaon to Tag 600, 601
# 	KS -> 2pi
# -> Event 374 Index 602 Length 3
# 	No Kaon to Tag 602, 603
# 	No Kaon to Tag 602, 604
# -> Event 375 Index 605 Length 1
# -> Event 376 Index 606 Length 1
# 	KS->2pi
# -> Event 377 Index 607 Length 3
# 	No Kaon to Tag 607, 608
# 	No Kaon to Tag 607, 609
# 	No Kaon to Tag 608, 609
# 	KS -> 2pi
# -> Event 378 Index 610 Length 2
# 	No Kaon to Tag 610, 611
# 	KS -> 2pi
# -> Event 379 Index 612 Length 1
# -> Event 380 Index 613 Length 1
# -> Event 381 Index 614 Length 1
# -> Event 382 Index 615 Length 2
# 	No Kaon to Tag 615, 616
# 	KS -> 2pi
# -> Event 383 Index 617 Length 1
# 	KS->2pi
# -> Event 384 Index 618 Length 3
# 	No Kaon to Tag 618, 619
# 	No Kaon to Tag 618, 620
# 	No Kaon to Tag 619, 620
# -> Event 385 Index 621 Length 1
# -> Event 386 Index 622 Length 3
# 	No Kaon to Tag 622, 623
# 	No Kaon to Tag 622, 624
# 	No Kaon to Tag 623, 624
# -> Event 387 Index 625 Length 2
# 	No Kaon to Tag 625, 626
# -> Event 388 Index 627 Length 1
# -> Event 389 Index 628 Length 2
# 	No Kaon to Tag 628, 629
# -> Event 390 Index 630 Length 1
# -> Event 391 Index 631 Length 1
# 	KS->2pi
# -> Event 392 Index 632 Length 1
# -> Event 393 Index 633 Length 1
# 	KS->2pi
# -> Event 394 Index 634 Length 3
# 	No Kaon to Tag 634, 636
# 	No Kaon to Tag 635, 636
# -> Event 395 Index 637 Length 1
# -> Event 396 Index 638 Length 3
# 	No Kaon to Tag 639, 640
# -> Event 397 Index 641 Length 3
# 	No Kaon to Tag 641, 642
# 	No Kaon to Tag 641, 643
# 	No Kaon to Tag 642, 643
# -> Event 398 Index 644 Length 1
# -> Event 399 Index 645 Length 3
# 	645 is a KS, 646 is a KL
# 	KS -> 2pi
# 	645 is a KS, 647 is a KL
# 	KS -> 2pi
# 	No Kaon to Tag 646, 647
# -> Event 400 Index 648 Length 1
# 	KS->2pi
# -> Event 401 Index 649 Length 1
# 	KS->2pi
# -> Event 402 Index 650 Length 1
# 	KS->2pi
# -> Event 403 Index 651 Length 1
# -> Event 404 Index 652 Length 1
# -> Event 405 Index 653 Length 1
# -> Event 406 Index 654 Length 1
# 	KS->2pi
# -> Event 407 Index 655 Length 1
# -> Event 408 Index 656 Length 2
# 	No Kaon to Tag 656, 657
# 	KS -> 2pi
# -> Event 409 Index 658 Length 1
# 	KS->2pi
# -> Event 410 Index 659 Length 1
# 	KS->2pi
# -> Event 411 Index 660 Length 1
# -> Event 412 Index 661 Length 2
# 	No Kaon to Tag 661, 662
# 	KS -> 2pi
# -> Event 413 Index 663 Length 1
# -> Event 414 Index 664 Length 1
# -> Event 415 Index 665 Length 2
# 	No Kaon to Tag 665, 666
# 	KS -> 2pi
# -> Event 416 Index 667 Length 1
# -> Event 417 Index 668 Length 1
# -> Event 418 Index 669 Length 1
# -> Event 419 Index 670 Length 1
# -> Event 420 Index 671 Length 1
# 	KS->2pi
# -> Event 421 Index 672 Length 1
# 	KS->2pi
# -> Event 422 Index 673 Length 1
# 	KS->2pi
# -> Event 423 Index 674 Length 1
# 	KS->2pi
# -> Event 424 Index 675 Length 4
# 	No Kaon to Tag 675, 676
# 	No Kaon to Tag 675, 678
# 	No Kaon to Tag 676, 677
# 	No Kaon to Tag 676, 678
# 	No Kaon to Tag 677, 678
# -> Event 425 Index 679 Length 1
# 	KS->2pi
# -> Event 426 Index 680 Length 1
# -> Event 427 Index 681 Length 1
# -> Event 428 Index 682 Length 1
# -> Event 429 Index 683 Length 1
# 	KS->2pi
# -> Event 430 Index 684 Length 1
# -> Event 431 Index 685 Length 1
# -> Event 432 Index 686 Length 1
# 	KS->2pi
# -> Event 433 Index 687 Length 1
# 	KS->2pi
# -> Event 434 Index 688 Length 2
# -> Event 435 Index 690 Length 3
# 	No Kaon to Tag 690, 692
# -> Event 436 Index 693 Length 1
# 	KS->2pi
# -> Event 437 Index 694 Length 1
# -> Event 438 Index 695 Length 1
# 	KS->2pi
# -> Event 439 Index 696 Length 2
# 	No Kaon to Tag 696, 697
# -> Event 440 Index 698 Length 1
# 	KS->2pi
# -> Event 441 Index 699 Length 1
# 	KS->2pi
# -> Event 442 Index 700 Length 1
# 	KS->2pi
# -> Event 443 Index 701 Length 1
# 	KS->2pi
# -> Event 444 Index 702 Length 2
# -> Event 445 Index 704 Length 1
# 	KS->2pi
# -> Event 446 Index 705 Length 1
# -> Event 447 Index 706 Length 3
# 	No Kaon to Tag 706, 708
# 	No Kaon to Tag 707, 708
# 	KS -> 2pi
# -> Event 448 Index 709 Length 2
# 	No Kaon to Tag 709, 710
# -> Event 449 Index 711 Length 2
# 	No Kaon to Tag 711, 712
# -> Event 450 Index 713 Length 5
# 	No Kaon to Tag 713, 714
# 	No Kaon to Tag 713, 717
# 	No Kaon to Tag 714, 715
# 	No Kaon to Tag 714, 716
# 	No Kaon to Tag 714, 717
# 	No Kaon to Tag 715, 716
# -> Event 451 Index 718 Length 1
# 	KS->2pi
# -> Event 452 Index 719 Length 2
# -> Event 453 Index 721 Length 1
# -> Event 454 Index 722 Length 2
# 	No Kaon to Tag 722, 723
# -> Event 455 Index 724 Length 2
# 	No Kaon to Tag 724, 725
# 	KS -> 2pi
# -> Event 456 Index 726 Length 1
# -> Event 457 Index 727 Length 1
# -> Event 458 Index 728 Length 1
# -> Event 459 Index 729 Length 2
# 	No Kaon to Tag 729, 730
# 	KS -> 2pi
# -> Event 460 Index 731 Length 2
# 	No Kaon to Tag 731, 732
# 	KS -> 2pi
# -> Event 461 Index 733 Length 1
# -> Event 462 Index 734 Length 1
# 	KS->2pi
# -> Event 463 Index 735 Length 1
# 	KS->2pi
# -> Event 464 Index 736 Length 3
# 	No Kaon to Tag 736, 737
# 	No Kaon to Tag 736, 738
# 	No Kaon to Tag 737, 738
# -> Event 465 Index 739 Length 5
# 	No Kaon to Tag 739, 740
# 	No Kaon to Tag 739, 741
# 	No Kaon to Tag 739, 743
# 	No Kaon to Tag 740, 741
# 	No Kaon to Tag 740, 742
# 	No Kaon to Tag 740, 743
# 	No Kaon to Tag 741, 743
# 	No Kaon to Tag 742, 743
# 	KS -> 2pi
# -> Event 466 Index 744 Length 2
# -> Event 467 Index 746 Length 1
# 	KS->2pi
# -> Event 468 Index 747 Length 1
# -> Event 469 Index 748 Length 1
# -> Event 470 Index 749 Length 2
# 	KS -> 2pi
# -> Event 471 Index 751 Length 1
# -> Event 472 Index 752 Length 2
# 	No Kaon to Tag 752, 753
# 	KS -> 2pi
# -> Event 473 Index 754 Length 1
# 	KS->2pi
# -> Event 474 Index 755 Length 1
# 	KS->2pi
# -> Event 475 Index 756 Length 2
# 	No Kaon to Tag 756, 757
# 	KS -> 2pi
# -> Event 476 Index 758 Length 1
# -> Event 477 Index 759 Length 1
# -> Event 478 Index 760 Length 1
# 	KS->2pi
# -> Event 479 Index 761 Length 1
# 	KS->2pi
# -> Event 480 Index 762 Length 3
# 	762 is a KS, 763 is a KL
# 	KS -> 2pi
# 	No Kaon to Tag 762, 764
# 	No Kaon to Tag 763, 764
# -> Event 481 Index 765 Length 2
# 	No Kaon to Tag 765, 766
# -> Event 482 Index 767 Length 3
# 	No Kaon to Tag 767, 769
# 	No Kaon to Tag 768, 769
# -> Event 483 Index 770 Length 1
# -> Event 484 Index 771 Length 1
# -> Event 485 Index 772 Length 1
# 	KS->2pi
# -> Event 486 Index 773 Length 2
# -> Event 487 Index 775 Length 5
# 	No Kaon to Tag 775, 776
# 	No Kaon to Tag 775, 777
# 	No Kaon to Tag 775, 778
# 	No Kaon to Tag 775, 779
# 	No Kaon to Tag 776, 778
# 	No Kaon to Tag 777, 779
# -> Event 488 Index 780 Length 5
# 	No Kaon to Tag 780, 781
# 	No Kaon to Tag 780, 783
# 	No Kaon to Tag 780, 784
# 	No Kaon to Tag 781, 782
# 	No Kaon to Tag 781, 783
# 	No Kaon to Tag 781, 784
# 	No Kaon to Tag 782, 784
# 	No Kaon to Tag 783, 784
# -> Event 489 Index 785 Length 1
# 	KS->2pi
# -> Event 490 Index 786 Length 1
# -> Event 491 Index 787 Length 3
# 	No Kaon to Tag 787, 788
# 	No Kaon to Tag 788, 789
# 	KS -> 2pi
# -> Event 492 Index 790 Length 3
# 	No Kaon to Tag 790, 791
# 	No Kaon to Tag 791, 792
# -> Event 493 Index 793 Length 1
# 	KS->2pi
# -> Event 494 Index 794 Length 1
# -> Event 495 Index 795 Length 3
# -> Event 496 Index 798 Length 1
# 	KS->2pi
# -> Event 497 Index 799 Length 2
# 	No Kaon to Tag 799, 800
# -> Event 498 Index 801 Length 3
# 	No Kaon to Tag 801, 802
# 	No Kaon to Tag 802, 803
# -> Event 499 Index 804 Length 1
# 	KS->2pi
# -> Event 500 Index 805 Length 1
# -> Event 501 Index 806 Length 1
# -> Event 502 Index 807 Length 1
# 	KS->2pi
# -> Event 503 Index 808 Length 1
# 	KS->2pi
# -> Event 504 Index 809 Length 1
# -> Event 505 Index 810 Length 1
# -> Event 506 Index 811 Length 1
# -> Event 507 Index 812 Length 1
# 	KS->2pi
# -> Event 508 Index 813 Length 1
# 	KS->2pi
# -> Event 509 Index 814 Length 4
# 	No Kaon to Tag 814, 815
# 	No Kaon to Tag 814, 817
# 	No Kaon to Tag 815, 817
# -> Event 510 Index 818 Length 2
# -> Event 511 Index 820 Length 1
# 	KS->2pi
# -> Event 512 Index 821 Length 2
# 	No Kaon to Tag 821, 822
# -> Event 513 Index 823 Length 1
# 	KS->2pi
# -> Event 514 Index 824 Length 1
# -> Event 515 Index 825 Length 1
# -> Event 516 Index 826 Length 2
# 	No Kaon to Tag 826, 827
# 	KS -> 2pi
# -> Event 517 Index 828 Length 1
# 	KS->2pi
# -> Event 518 Index 829 Length 1
# -> Event 519 Index 830 Length 2
# 	No Kaon to Tag 830, 831
# -> Event 520 Index 832 Length 2
# -> Event 521 Index 834 Length 1
# -> Event 522 Index 835 Length 1
# 	KS->2pi
# -> Event 523 Index 836 Length 1
# -> Event 524 Index 837 Length 2
# -> Event 525 Index 839 Length 1
# -> Event 526 Index 840 Length 1
# -> Event 527 Index 841 Length 2
# 	No Kaon to Tag 841, 842
# 	KS -> 2pi
# -> Event 528 Index 843 Length 1
# -> Event 529 Index 844 Length 1
# 	KS->2pi
# -> Event 530 Index 845 Length 1
# 	KS->2pi
# -> Event 531 Index 846 Length 3
# 	No Kaon to Tag 847, 848
# -> Event 532 Index 849 Length 1
# 	KS->2pi
# -> Event 533 Index 850 Length 2
# -> Event 534 Index 852 Length 1
# -> Event 535 Index 853 Length 1
# 	KS->2pi
# -> Event 536 Index 854 Length 1
# -> Event 537 Index 855 Length 2
# 	No Kaon to Tag 855, 856
# -> Event 538 Index 857 Length 2
# 	No Kaon to Tag 857, 858
# -> Event 539 Index 859 Length 4
# 	No Kaon to Tag 859, 860
# 	859 is a KS, 861 is a KL
# 	KS -> 2pi
# 	No Kaon to Tag 859, 862
# 	No Kaon to Tag 860, 861
# -> Event 540 Index 863 Length 1
# -> Event 541 Index 864 Length 4
# 	No Kaon to Tag 864, 867
# 	No Kaon to Tag 865, 866
# -> Event 542 Index 868 Length 1
# 	KS->2pi
# -> Event 543 Index 869 Length 1
# -> Event 544 Index 870 Length 3
# 	No Kaon to Tag 870, 871
# 	KS -> 2pi
# -> Event 545 Index 873 Length 2
# 	No Kaon to Tag 873, 874
# -> Event 546 Index 875 Length 1
# -> Event 547 Index 876 Length 1
# 	KS->2pi
# -> Event 548 Index 877 Length 1
# -> Event 549 Index 878 Length 1
# 	KS->2pi
# -> Event 550 Index 879 Length 1
# 	KS->2pi
# -> Event 551 Index 880 Length 1
# 	KS->2pi
# -> Event 552 Index 881 Length 1
# -> Event 553 Index 882 Length 1
# -> Event 554 Index 883 Length 1
# 	KS->2pi
# -> Event 555 Index 884 Length 1
# -> Event 556 Index 885 Length 1
# 	KS->2pi
# -> Event 557 Index 886 Length 2
# 	No Kaon to Tag 886, 887
# -> Event 558 Index 888 Length 6
# 	No Kaon to Tag 888, 890
# 	No Kaon to Tag 888, 893
# 	No Kaon to Tag 889, 890
# 	No Kaon to Tag 889, 891
# 	No Kaon to Tag 889, 892
# 	No Kaon to Tag 889, 893
# 	No Kaon to Tag 890, 891
# 	No Kaon to Tag 890, 892
# 	No Kaon to Tag 891, 892
# 	No Kaon to Tag 891, 893
# 	No Kaon to Tag 892, 893
# -> Event 559 Index 894 Length 2
# 	No Kaon to Tag 894, 895
# -> Event 560 Index 896 Length 2
# 	No Kaon to Tag 896, 897
# -> Event 561 Index 898 Length 1
# -> Event 562 Index 899 Length 1
# -> Event 563 Index 900 Length 1
# 	KS->2pi
# -> Event 564 Index 901 Length 1
# 	KS->2pi
# -> Event 565 Index 902 Length 2
# 	No Kaon to Tag 902, 903
# -> Event 566 Index 904 Length 1
# 	KS->2pi
# -> Event 567 Index 905 Length 3
# 	No Kaon to Tag 905, 906
# 	No Kaon to Tag 906, 907
# -> Event 568 Index 908 Length 1
# -> Event 569 Index 909 Length 2
# 	No Kaon to Tag 909, 910
# -> Event 570 Index 911 Length 1
# -> Event 571 Index 912 Length 1
# -> Event 572 Index 913 Length 2
# 	No Kaon to Tag 913, 914
# 	KS -> 2pi
# -> Event 573 Index 915 Length 1
# 	KS->2pi
# -> Event 574 Index 916 Length 3
# 	No Kaon to Tag 916, 917
# 	No Kaon to Tag 916, 918
# 	No Kaon to Tag 917, 918
# 	KS -> 2pi
# -> Event 575 Index 919 Length 1
# 	KS->2pi
# -> Event 576 Index 920 Length 1
# -> Event 577 Index 921 Length 1
# 	KS->2pi
# -> Event 578 Index 922 Length 1
# 	KS->2pi
# -> Event 579 Index 923 Length 2
# 	No Kaon to Tag 923, 924
# 	KS -> 2pi
# -> Event 580 Index 925 Length 1
# -> Event 581 Index 926 Length 2
# 	No Kaon to Tag 926, 927
# -> Event 582 Index 928 Length 2
# -> Event 583 Index 930 Length 2
# -> Event 584 Index 932 Length 1
# 	KS->2pi
# -> Event 585 Index 933 Length 1
# -> Event 586 Index 934 Length 3
# 	No Kaon to Tag 934, 935
# 	No Kaon to Tag 934, 936
# 	No Kaon to Tag 935, 936
# -> Event 587 Index 937 Length 1
# 	KS->2pi
# -> Event 588 Index 938 Length 3
# 	No Kaon to Tag 938, 940
# 	No Kaon to Tag 939, 940
# -> Event 589 Index 941 Length 1
# -> Event 590 Index 942 Length 1
# -> Event 591 Index 943 Length 1
# -> Event 592 Index 944 Length 1
# -> Event 593 Index 945 Length 2
# 	No Kaon to Tag 945, 946
# -> Event 594 Index 947 Length 1
# 	KS->2pi
# -> Event 595 Index 948 Length 1
# -> Event 596 Index 949 Length 1
# -> Event 597 Index 950 Length 2
# 	No Kaon to Tag 950, 951
# -> Event 598 Index 952 Length 2
# 	No Kaon to Tag 952, 953
# -> Event 599 Index 954 Length 1
# -> Event 600 Index 955 Length 1
# -> Event 601 Index 956 Length 2
# -> Event 602 Index 958 Length 1
# -> Event 603 Index 959 Length 1
# 	KS->2pi
# -> Event 604 Index 960 Length 1
# 	KS->2pi
# -> Event 605 Index 961 Length 1
# 	KS->2pi
# -> Event 606 Index 962 Length 1
# -> Event 607 Index 963 Length 1
# 	KS->2pi
# -> Event 608 Index 964 Length 1
# 	KS->2pi
# -> Event 609 Index 965 Length 1
# 	KS->2pi
# -> Event 610 Index 966 Length 1
# 	KS->2pi
# -> Event 611 Index 967 Length 1
# -> Event 612 Index 968 Length 1
# -> Event 613 Index 969 Length 1
# 	KS->2pi
# -> Event 614 Index 970 Length 1
# 	KS->2pi
# -> Event 615 Index 971 Length 1
# -> Event 616 Index 972 Length 2
# -> Event 617 Index 974 Length 3
# 	No Kaon to Tag 974, 975
# 	No Kaon to Tag 974, 976
# 	No Kaon to Tag 975, 976
# -> Event 618 Index 977 Length 2
# 	No Kaon to Tag 977, 978
# -> Event 619 Index 979 Length 1
# -> Event 620 Index 980 Length 1
# -> Event 621 Index 981 Length 3
# 	No Kaon to Tag 981, 982
# 	No Kaon to Tag 981, 983
# 	No Kaon to Tag 982, 983
# -> Event 622 Index 984 Length 2
# -> Event 623 Index 986 Length 1
# 	KS->2pi
# -> Event 624 Index 987 Length 1
# 	KS->2pi
# -> Event 625 Index 988 Length 1
# 	KS->2pi
# -> Event 626 Index 989 Length 4
# 	No Kaon to Tag 989, 990
# 	No Kaon to Tag 989, 992
# 	No Kaon to Tag 990, 991
# 	No Kaon to Tag 990, 992
# 	991 is a KS, 992 is a KL
# -> Event 627 Index 993 Length 2
# 	No Kaon to Tag 993, 994
# -> Event 628 Index 995 Length 2
# 	No Kaon to Tag 995, 996
# -> Event 629 Index 997 Length 2
# 	No Kaon to Tag 997, 998
# 	KS -> 2pi
# -> Event 630 Index 999 Length 1
# 	KS->2pi
# -> Event 631 Index 1000 Length 2
# 	No Kaon to Tag 1000, 1001
# -> Event 632 Index 1002 Length 1
# -> Event 633 Index 1003 Length 1
# -> Event 634 Index 1004 Length 1
# -> Event 635 Index 1005 Length 2
# 	No Kaon to Tag 1005, 1006
# -> Event 636 Index 1007 Length 2
# 	No Kaon to Tag 1007, 1008
# -> Event 637 Index 1009 Length 2
# 	No Kaon to Tag 1009, 1010
# -> Event 638 Index 1011 Length 2
# 	No Kaon to Tag 1011, 1012
# -> Event 639 Index 1013 Length 1
# -> Event 640 Index 1014 Length 1
# -> Event 641 Index 1015 Length 1
# 	KS->2pi
# -> Event 642 Index 1016 Length 1
# -> Event 643 Index 1017 Length 2
# 	1017 is a KS, 1018 is a KL
# -> Event 644 Index 1019 Length 1
# -> Event 645 Index 1020 Length 1
# 	KS->2pi
# -> Event 646 Index 1021 Length 3
# 	No Kaon to Tag 1021, 1022
# 	No Kaon to Tag 1021, 1023
# 	No Kaon to Tag 1022, 1023
# 	KS -> 2pi
# -> Event 647 Index 1024 Length 2
# 	No Kaon to Tag 1024, 1025
# 	KS -> 2pi
# -> Event 648 Index 1026 Length 1
# 	KS->2pi
# -> Event 649 Index 1027 Length 1
# 	KS->2pi
# -> Event 650 Index 1028 Length 2
# 	No Kaon to Tag 1028, 1029
# 	KS -> 2pi
# -> Event 651 Index 1030 Length 1
# -> Event 652 Index 1031 Length 3
# 	No Kaon to Tag 1031, 1032
# -> Event 653 Index 1034 Length 1
# 	KS->2pi
# -> Event 654 Index 1035 Length 1
# -> Event 655 Index 1036 Length 2
# 	No Kaon to Tag 1036, 1037
# -> Event 656 Index 1038 Length 1
# -> Event 657 Index 1039 Length 1
# -> Event 658 Index 1040 Length 2
# 	No Kaon to Tag 1040, 1041
# 	KS -> 2pi
# -> Event 659 Index 1042 Length 1
# 	KS->2pi
# -> Event 660 Index 1043 Length 2
# 	No Kaon to Tag 1043, 1044
# -> Event 661 Index 1045 Length 3
# 	No Kaon to Tag 1045, 1046
# 	No Kaon to Tag 1045, 1047
# 	No Kaon to Tag 1046, 1047
# -> Event 662 Index 1048 Length 3
# 	No Kaon to Tag 1048, 1049
# 	No Kaon to Tag 1048, 1050
# -> Event 663 Index 1051 Length 2
# 	No Kaon to Tag 1051, 1052
# -> Event 664 Index 1053 Length 2
# 	No Kaon to Tag 1053, 1054
# -> Event 665 Index 1055 Length 1
# -> Event 666 Index 1056 Length 1
# 	KS->2pi
# -> Event 667 Index 1057 Length 1
# 	KS->2pi
# -> Event 668 Index 1058 Length 2
# 	No Kaon to Tag 1058, 1059
# -> Event 669 Index 1060 Length 1
# -> Event 670 Index 1061 Length 1
# -> Event 671 Index 1062 Length 1
# -> Event 672 Index 1063 Length 1
# 	KS->2pi
# -> Event 673 Index 1064 Length 4
# 	No Kaon to Tag 1064, 1065
# 	No Kaon to Tag 1065, 1066
# 	No Kaon to Tag 1065, 1067
# -> Event 674 Index 1068 Length 1
# -> Event 675 Index 1069 Length 1
# 	KS->2pi
# -> Event 676 Index 1070 Length 1
# -> Event 677 Index 1071 Length 1
# -> Event 678 Index 1072 Length 1
# 	KS->2pi
# -> Event 679 Index 1073 Length 3
# 	No Kaon to Tag 1073, 1074
# 	No Kaon to Tag 1073, 1075
# -> Event 680 Index 1076 Length 1
# 	KS->2pi
# -> Event 681 Index 1077 Length 1
# -> Event 682 Index 1078 Length 1
# -> Event 683 Index 1079 Length 1
# -> Event 684 Index 1080 Length 1
# 	KS->2pi
# -> Event 685 Index 1081 Length 2
# 	No Kaon to Tag 1081, 1082
# 	KS -> 2pi
# -> Event 686 Index 1083 Length 1
# -> Event 687 Index 1084 Length 1
# 	KS->2pi
# -> Event 688 Index 1085 Length 1
# 	KS->2pi
# -> Event 689 Index 1086 Length 2
# 	No Kaon to Tag 1086, 1087
# 	KS -> 2pi
# -> Event 690 Index 1088 Length 1
# 	KS->2pi
# -> Event 691 Index 1089 Length 2
# -> Event 692 Index 1091 Length 2
# 	No Kaon to Tag 1091, 1092
# -> Event 693 Index 1093 Length 2
# 	1093 is a KS, 1094 is a KL
# -> Event 694 Index 1095 Length 3
# 	No Kaon to Tag 1095, 1096
# 	No Kaon to Tag 1095, 1097
# -> Event 695 Index 1098 Length 1
# -> Event 696 Index 1099 Length 3
# 	No Kaon to Tag 1099, 1100
# 	No Kaon to Tag 1100, 1101
# 	KS -> 2pi
# -> Event 697 Index 1102 Length 1
# 	KS->2pi
# -> Event 698 Index 1103 Length 2
# 	No Kaon to Tag 1103, 1104
# -> Event 699 Index 1105 Length 1
# -> Event 700 Index 1106 Length 1
# 	KS->2pi
# -> Event 701 Index 1107 Length 1
# -> Event 702 Index 1108 Length 1
# 	KS->2pi
# -> Event 703 Index 1109 Length 1
# 	KS->2pi
# -> Event 704 Index 1110 Length 4
# 	No Kaon to Tag 1110, 1112
# 	No Kaon to Tag 1111, 1112
# 	No Kaon to Tag 1111, 1113
# 	No Kaon to Tag 1112, 1113
# -> Event 705 Index 1114 Length 1
# 	KS->2pi
# -> Event 706 Index 1115 Length 1
# -> Event 707 Index 1116 Length 1
# 	KS->2pi
# -> Event 708 Index 1117 Length 1
# -> Event 709 Index 1118 Length 1
# -> Event 710 Index 1119 Length 1
# 	KS->2pi
# -> Event 711 Index 1120 Length 1
# 	KS->2pi
# -> Event 712 Index 1121 Length 2
# 	No Kaon to Tag 1121, 1122
# -> Event 713 Index 1123 Length 1
# 	KS->2pi
# -> Event 714 Index 1124 Length 1
# -> Event 715 Index 1125 Length 1
# -> Event 716 Index 1126 Length 1
# 	KS->2pi
# -> Event 717 Index 1127 Length 1
# -> Event 718 Index 1128 Length 2
# 	No Kaon to Tag 1128, 1129
# -> Event 719 Index 1130 Length 2
# 	No Kaon to Tag 1130, 1131
# 	KS -> 2pi
# -> Event 720 Index 1132 Length 1
# 	KS->2pi
# -> Event 721 Index 1133 Length 2
# 	No Kaon to Tag 1133, 1134
# -> Event 722 Index 1135 Length 2
# 	KS -> 2pi
# -> Event 723 Index 1137 Length 2
# 	No Kaon to Tag 1137, 1138
# 	KS -> 2pi
# -> Event 724 Index 1139 Length 1
# 	KS->2pi
# -> Event 725 Index 1140 Length 1
# 	KS->2pi
# -> Event 726 Index 1141 Length 1
# -> Event 727 Index 1142 Length 1
# -> Event 728 Index 1143 Length 3
# 	No Kaon to Tag 1143, 1144
# 	No Kaon to Tag 1144, 1145
# -> Event 729 Index 1146 Length 2
# 	No Kaon to Tag 1146, 1147
# 	KS -> 2pi
# -> Event 730 Index 1148 Length 1
# 	KS->2pi
# -> Event 731 Index 1149 Length 5
# 	No Kaon to Tag 1149, 1151
# 	No Kaon to Tag 1149, 1152
# 	No Kaon to Tag 1149, 1153
# 	No Kaon to Tag 1150, 1151
# 	No Kaon to Tag 1150, 1152
# 	No Kaon to Tag 1150, 1153
# 	No Kaon to Tag 1151, 1152
# 	No Kaon to Tag 1151, 1153
# 	No Kaon to Tag 1152, 1153
# -> Event 732 Index 1154 Length 1
# 	KS->2pi
# -> Event 733 Index 1155 Length 2
# 	KS -> 2pi
# -> Event 734 Index 1157 Length 2
# 	No Kaon to Tag 1157, 1158
# 	KS -> 2pi
# -> Event 735 Index 1159 Length 1
# 	KS->2pi
# -> Event 736 Index 1160 Length 1
# 	KS->2pi
# -> Event 737 Index 1161 Length 1
# -> Event 738 Index 1162 Length 2
# 	No Kaon to Tag 1162, 1163
# -> Event 739 Index 1164 Length 1
# -> Event 740 Index 1165 Length 2
# -> Event 741 Index 1167 Length 1
# -> Event 742 Index 1168 Length 1
# -> Event 743 Index 1169 Length 2
# 	No Kaon to Tag 1169, 1170
# 	KS -> 2pi
# -> Event 744 Index 1171 Length 1
# -> Event 745 Index 1172 Length 1
# -> Event 746 Index 1173 Length 1
# -> Event 747 Index 1174 Length 1
# -> Event 748 Index 1175 Length 2
# 	No Kaon to Tag 1175, 1176
# -> Event 749 Index 1177 Length 1
# -> Event 750 Index 1178 Length 1
# -> Event 751 Index 1179 Length 1
# -> Event 752 Index 1180 Length 1
# -> Event 753 Index 1181 Length 1
# 	KS->2pi
# -> Event 754 Index 1182 Length 2
# -> Event 755 Index 1184 Length 3
# 	No Kaon to Tag 1184, 1185
# 	No Kaon to Tag 1184, 1186
# 	No Kaon to Tag 1185, 1186
# -> Event 756 Index 1187 Length 3
# 	No Kaon to Tag 1187, 1188
# 	No Kaon to Tag 1187, 1189
# 	KS -> 2pi
# -> Event 757 Index 1190 Length 3
# 	No Kaon to Tag 1190, 1191
# 	No Kaon to Tag 1190, 1192
# 	No Kaon to Tag 1191, 1192
# -> Event 758 Index 1193 Length 1
# -> Event 759 Index 1194 Length 1
# -> Event 760 Index 1195 Length 1
# -> Event 761 Index 1196 Length 1
# -> Event 762 Index 1197 Length 1
# 	KS->2pi
# -> Event 763 Index 1198 Length 1
# -> Event 764 Index 1199 Length 2
# 	No Kaon to Tag 1199, 1200
# 	KS -> 2pi
# -> Event 765 Index 1201 Length 1
# 	KS->2pi
# -> Event 766 Index 1202 Length 1
# 	KS->2pi
# -> Event 767 Index 1203 Length 2
# 	1203 is a KS, 1204 is a KL
# 	KS -> 2pi
# -> Event 768 Index 1205 Length 1
# 	KS->2pi
# -> Event 769 Index 1206 Length 2
# 	No Kaon to Tag 1206, 1207
# -> Event 770 Index 1208 Length 1
# -> Event 771 Index 1209 Length 5
# 	No Kaon to Tag 1209, 1210
# 	No Kaon to Tag 1209, 1211
# 	No Kaon to Tag 1209, 1212
# 	No Kaon to Tag 1209, 1213
# 	No Kaon to Tag 1210, 1211
# 	No Kaon to Tag 1210, 1213
# 	No Kaon to Tag 1211, 1212
# 	No Kaon to Tag 1211, 1213
# 	No Kaon to Tag 1212, 1213
# 	KS -> 2pi
# -> Event 772 Index 1214 Length 3
# 	No Kaon to Tag 1214, 1215
# 	No Kaon to Tag 1214, 1216
# 	No Kaon to Tag 1215, 1216
# 	KS -> 2pi
# -> Event 773 Index 1217 Length 1
# 	KS->2pi
# -> Event 774 Index 1218 Length 1
# -> Event 775 Index 1219 Length 2
# 	No Kaon to Tag 1219, 1220
# -> Event 776 Index 1221 Length 1
# -> Event 777 Index 1222 Length 1
# 	KS->2pi
# -> Event 778 Index 1223 Length 1
# -> Event 779 Index 1224 Length 1
# -> Event 780 Index 1225 Length 1
# 	KS->2pi
# -> Event 781 Index 1226 Length 2
# 	No Kaon to Tag 1226, 1227
# 	KS -> 2pi
# -> Event 782 Index 1228 Length 1
# -> Event 783 Index 1229 Length 1
# -> Event 784 Index 1230 Length 1
# 	KS->2pi
# -> Event 785 Index 1231 Length 1
# 	KS->2pi
# -> Event 786 Index 1232 Length 1
# 	KS->2pi
# -> Event 787 Index 1233 Length 1
# 	KS->2pi
# -> Event 788 Index 1234 Length 3
# 	No Kaon to Tag 1234, 1235
# 	No Kaon to Tag 1234, 1236
# 	No Kaon to Tag 1235, 1236
# -> Event 789 Index 1237 Length 1
# -> Event 790 Index 1238 Length 1
# -> Event 791 Index 1239 Length 3
# 	No Kaon to Tag 1239, 1240
# 	No Kaon to Tag 1239, 1241
# -> Event 792 Index 1242 Length 1
# -> Event 793 Index 1243 Length 1
# -> Event 794 Index 1244 Length 2
# 	No Kaon to Tag 1244, 1245
# 	KS -> 2pi
# -> Event 795 Index 1246 Length 1
# 	KS->2pi
# -> Event 796 Index 1247 Length 2
# -> Event 797 Index 1249 Length 2
# 	No Kaon to Tag 1249, 1250
# 	KS -> 2pi
# -> Event 798 Index 1251 Length 1
# 	KS->2pi
# -> Event 799 Index 1252 Length 1
# 	KS->2pi
# -> Event 800 Index 1253 Length 2
# 	1254 is a KS, 1253 is a KL
# -> Event 801 Index 1255 Length 1
# -> Event 802 Index 1256 Length 1
# 	KS->2pi
# -> Event 803 Index 1257 Length 1
# 	KS->2pi
# -> Event 804 Index 1258 Length 1
# 	KS->2pi
# -> Event 805 Index 1259 Length 1
# 	KS->2pi
# -> Event 806 Index 1260 Length 2
# 	1260 is a KS, 1261 is a KL
# 	KS -> 2pi
# -> Event 807 Index 1262 Length 1
# 	KS->2pi
# -> Event 808 Index 1263 Length 1
# 	KS->2pi
# -> Event 809 Index 1264 Length 1
# -> Event 810 Index 1265 Length 1
# 	KS->2pi
# -> Event 811 Index 1266 Length 1
# -> Event 812 Index 1267 Length 3
# 	No Kaon to Tag 1267, 1268
# 	No Kaon to Tag 1267, 1269
# -> Event 813 Index 1270 Length 1
# 	KS->2pi
# -> Event 814 Index 1271 Length 1
# -> Event 815 Index 1272 Length 3
# 	No Kaon to Tag 1272, 1273
# 	No Kaon to Tag 1272, 1274
# 	No Kaon to Tag 1273, 1274
# 	KS -> 2pi
# -> Event 816 Index 1275 Length 1
# -> Event 817 Index 1276 Length 1
# -> Event 818 Index 1277 Length 1
# 	KS->2pi
# -> Event 819 Index 1278 Length 1
# 	KS->2pi
# -> Event 820 Index 1279 Length 1
# -> Event 821 Index 1280 Length 2
# 	No Kaon to Tag 1280, 1281
# -> Event 822 Index 1282 Length 1
# 	KS->2pi
# -> Event 823 Index 1283 Length 2
# -> Event 824 Index 1285 Length 1
# -> Event 825 Index 1286 Length 2
# 	No Kaon to Tag 1286, 1287
# -> Event 826 Index 1288 Length 1
# -> Event 827 Index 1289 Length 1
# -> Event 828 Index 1290 Length 1
# 	KS->2pi
# -> Event 829 Index 1291 Length 2
# 	No Kaon to Tag 1291, 1292
# 	KS -> 2pi
# -> Event 830 Index 1293 Length 1
# 	KS->2pi
# -> Event 831 Index 1294 Length 1
# -> Event 832 Index 1295 Length 1
# 	KS->2pi
# -> Event 833 Index 1296 Length 1
# -> Event 834 Index 1297 Length 2
# 	No Kaon to Tag 1297, 1298
# 	KS -> 2pi
# -> Event 835 Index 1299 Length 1
# -> Event 836 Index 1300 Length 1
# 	KS->2pi
# -> Event 837 Index 1301 Length 2
# 	No Kaon to Tag 1301, 1302
# 	KS -> 2pi
# -> Event 838 Index 1303 Length 1
# 	KS->2pi
# -> Event 839 Index 1304 Length 3
# 	1306 is a KS, 1304 is a KL
# 	No Kaon to Tag 1305, 1306
# -> Event 840 Index 1307 Length 2
# 	No Kaon to Tag 1307, 1308
# 	KS -> 2pi
# -> Event 841 Index 1309 Length 3
# 	No Kaon to Tag 1309, 1311
# 	No Kaon to Tag 1310, 1311
# -> Event 842 Index 1312 Length 2
# 	KS -> 2pi
# -> Event 843 Index 1314 Length 2
# 	No Kaon to Tag 1314, 1315
# -> Event 844 Index 1316 Length 2
# -> Event 845 Index 1318 Length 1
# -> Event 846 Index 1319 Length 1
# 	KS->2pi
# -> Event 847 Index 1320 Length 2
# 	KS -> 2pi
# -> Event 848 Index 1322 Length 2
# 	No Kaon to Tag 1322, 1323
# -> Event 849 Index 1324 Length 2
# -> Event 850 Index 1326 Length 2
# 	No Kaon to Tag 1326, 1327
# -> Event 851 Index 1328 Length 1
# 	KS->2pi
# -> Event 852 Index 1329 Length 1
# 	KS->2pi
# -> Event 853 Index 1330 Length 1
# -> Event 854 Index 1331 Length 1
# 	KS->2pi
# -> Event 855 Index 1332 Length 1
# 	KS->2pi
# -> Event 856 Index 1333 Length 2
# 	No Kaon to Tag 1333, 1334
# -> Event 857 Index 1335 Length 1
# 	KS->2pi
# -> Event 858 Index 1336 Length 3
# 	No Kaon to Tag 1336, 1337
# 	No Kaon to Tag 1337, 1338
# 	KS -> 2pi
# -> Event 859 Index 1339 Length 2
# -> Event 860 Index 1341 Length 1
# -> Event 861 Index 1342 Length 1
# -> Event 862 Index 1343 Length 1
# 	KS->2pi
# -> Event 863 Index 1344 Length 1
# -> Event 864 Index 1345 Length 1
# -> Event 865 Index 1346 Length 1
# 	KS->2pi
# -> Event 866 Index 1347 Length 1
# 	KS->2pi
# -> Event 867 Index 1348 Length 1
# -> Event 868 Index 1349 Length 5
# 	No Kaon to Tag 1349, 1350
# 	No Kaon to Tag 1349, 1351
# 	No Kaon to Tag 1349, 1353
# 	No Kaon to Tag 1350, 1351
# 	No Kaon to Tag 1350, 1352
# 	No Kaon to Tag 1350, 1353
# 	No Kaon to Tag 1351, 1353
# 	No Kaon to Tag 1352, 1353
# -> Event 869 Index 1354 Length 2
# 	No Kaon to Tag 1354, 1355
# 	KS -> 2pi
# -> Event 870 Index 1356 Length 1
# -> Event 871 Index 1357 Length 1
# 	KS->2pi
# -> Event 872 Index 1358 Length 1
# -> Event 873 Index 1359 Length 1
# 	KS->2pi
# -> Event 874 Index 1360 Length 2
# 	No Kaon to Tag 1360, 1361
# -> Event 875 Index 1362 Length 1
# -> Event 876 Index 1363 Length 1
# 	KS->2pi
# -> Event 877 Index 1364 Length 1
# -> Event 878 Index 1365 Length 1
# -> Event 879 Index 1366 Length 1
# 	KS->2pi
# -> Event 880 Index 1367 Length 1
# -> Event 881 Index 1368 Length 1
# 	KS->2pi
# -> Event 882 Index 1369 Length 2
# 	No Kaon to Tag 1369, 1370
# -> Event 883 Index 1371 Length 2
# 	No Kaon to Tag 1371, 1372
# 	KS -> 2pi
# -> Event 884 Index 1373 Length 2
# 	No Kaon to Tag 1373, 1374
# 	KS -> 2pi
# -> Event 885 Index 1375 Length 1
# 	KS->2pi
# -> Event 886 Index 1376 Length 3
# 	No Kaon to Tag 1377, 1378
# -> Event 887 Index 1379 Length 1
# -> Event 888 Index 1380 Length 1
# -> Event 889 Index 1381 Length 1
# -> Event 890 Index 1382 Length 1
# -> Event 891 Index 1383 Length 2
# -> Event 892 Index 1385 Length 2
# 	No Kaon to Tag 1385, 1386
# 	KS -> 2pi
# -> Event 893 Index 1387 Length 2
# 	No Kaon to Tag 1387, 1388
# 	KS -> 2pi
# -> Event 894 Index 1389 Length 2
# -> Event 895 Index 1391 Length 2
# 	No Kaon to Tag 1391, 1392
# -> Event 896 Index 1393 Length 1
# 	KS->2pi
# -> Event 897 Index 1394 Length 1
# -> Event 898 Index 1395 Length 1
# 	KS->2pi
# -> Event 899 Index 1396 Length 1
# 	KS->2pi
# -> Event 900 Index 1397 Length 1
# -> Event 901 Index 1398 Length 2
# 	No Kaon to Tag 1398, 1399
# -> Event 902 Index 1400 Length 1
# 	KS->2pi
# -> Event 903 Index 1401 Length 1
# 	KS->2pi
# -> Event 904 Index 1402 Length 1
# 	KS->2pi
# -> Event 905 Index 1403 Length 4
# 	No Kaon to Tag 1403, 1405
# 	No Kaon to Tag 1403, 1406
# 	No Kaon to Tag 1404, 1405
# 	No Kaon to Tag 1404, 1406
# 	No Kaon to Tag 1405, 1406
# -> Event 906 Index 1407 Length 2
# 	No Kaon to Tag 1407, 1408
# -> Event 907 Index 1409 Length 1
# -> Event 908 Index 1410 Length 1
# 	KS->2pi
# -> Event 909 Index 1411 Length 3
# 	No Kaon to Tag 1411, 1412
# 	KS -> 2pi
# -> Event 910 Index 1414 Length 2
# 	No Kaon to Tag 1414, 1415
# 	KS -> 2pi
# -> Event 911 Index 1416 Length 1
# 	KS->2pi
# -> Event 912 Index 1417 Length 3
# ...
# -> Event 39851 Index 62623 Length 1
# -> Event 39852 Index 62624 Length 2
# -> Event 39853 Index 62626 Length 2
# 	No Kaon to Tag 62626, 62627
# -> Event 39854 Index 62628 Length 2
# 	No Kaon to Tag 62628, 62629
# 	KS -> 2pi
# -> Event 39855 Index 62630 Length 1
# 	KS->2pi
# -> Event 39856 Index 62631 Length 1
# 	KS->2pi
# -> Event 39857 Index 62632 Length 1
# -> Event 39858 Index 62633 Length 2
# -> Event 39859 Index 62635 Length 1
# 	KS->2pi
# -> Event 39860 Index 62636 Length 1
# -> Event 39861 Index 62637 Length 1
# 	KS->2pi
# -> Event 39862 Index 62638 Length 1
# 	KS->2pi
# -> Event 39863 Index 62639 Length 1
# 	KS->2pi
# -> Event 39864 Index 62640 Length 1
# -> Event 39865 Index 62641 Length 1
# -> Event 39866 Index 62642 Length 1
# -> Event 39867 Index 62643 Length 3
# 	No Kaon to Tag 62643, 62644
# 	No Kaon to Tag 62643, 62645
# 	No Kaon to Tag 62644, 62645
# 	KS -> 2pi
# -> Event 39868 Index 62646 Length 2
# -> Event 39869 Index 62648 Length 3
# 	No Kaon to Tag 62648, 62649
# 	62648 is a KS, 62650 is a KL
# 	KS -> 2pi
# 	No Kaon to Tag 62649, 62650
# -> Event 39870 Index 62651 Length 2
# 	No Kaon to Tag 62651, 62652
# -> Event 39871 Index 62653 Length 1
# 	KS->2pi
# -> Event 39872 Index 62654 Length 1
# 	KS->2pi
# -> Event 39873 Index 62655 Length 1
# 	KS->2pi
# -> Event 39874 Index 62656 Length 2
# 	No Kaon to Tag 62656, 62657
# 	KS -> 2pi
# -> Event 39875 Index 62658 Length 2
# 	No Kaon to Tag 62658, 62659
# 	KS -> 2pi
# -> Event 39876 Index 62660 Length 1
# -> Event 39877 Index 62661 Length 1
# 	KS->2pi
# -> Event 39878 Index 62662 Length 8
# 	No Kaon to Tag 62662, 62663
# 	No Kaon to Tag 62662, 62664
# 	No Kaon to Tag 62662, 62665
# 	No Kaon to Tag 62662, 62667
# 	No Kaon to Tag 62662, 62668
# 	No Kaon to Tag 62662, 62669
# 	No Kaon to Tag 62663, 62664
# 	No Kaon to Tag 62663, 62666
# 	No Kaon to Tag 62663, 62667
# 	No Kaon to Tag 62664, 62665
# 	No Kaon to Tag 62664, 62666
# 	No Kaon to Tag 62664, 62667
# 	No Kaon to Tag 62664, 62668
# 	No Kaon to Tag 62664, 62669
# 	No Kaon to Tag 62665, 62668
# 	No Kaon to Tag 62665, 62669
# 	No Kaon to Tag 62666, 62667
# 	No Kaon to Tag 62668, 62669
# 	KS -> 2pi
# -> Event 39879 Index 62670 Length 3
# 	No Kaon to Tag 62670, 62672
# 	No Kaon to Tag 62671, 62672
# -> Event 39880 Index 62673 Length 1
# -> Event 39881 Index 62674 Length 2
# 	No Kaon to Tag 62674, 62675
# -> Event 39882 Index 62676 Length 3
# 	No Kaon to Tag 62676, 62678
# 	KS -> 2pi
# -> Event 39883 Index 62679 Length 1
# 	KS->2pi
# -> Event 39884 Index 62680 Length 1
# -> Event 39885 Index 62681 Length 4
# 	No Kaon to Tag 62681, 62683
# 	No Kaon to Tag 62682, 62683
# 	No Kaon to Tag 62682, 62684
# 	No Kaon to Tag 62683, 62684
# 	KS -> 2pi
# -> Event 39886 Index 62685 Length 1
# 	KS->2pi
# -> Event 39887 Index 62686 Length 1
# -> Event 39888 Index 62687 Length 1
# -> Event 39889 Index 62688 Length 4
# 	No Kaon to Tag 62688, 62689
# 	No Kaon to Tag 62688, 62690
# 	No Kaon to Tag 62688, 62691
# 	No Kaon to Tag 62689, 62690
# -> Event 39890 Index 62692 Length 1
# -> Event 39891 Index 62693 Length 2
# 	No Kaon to Tag 62693, 62694
# 	KS -> 2pi
# -> Event 39892 Index 62695 Length 2
# 	No Kaon to Tag 62695, 62696
# 	KS -> 2pi
# -> Event 39893 Index 62697 Length 1
# 	KS->2pi
# -> Event 39894 Index 62698 Length 1
# -> Event 39895 Index 62699 Length 1
# 	KS->2pi
# -> Event 39896 Index 62700 Length 3
# 	No Kaon to Tag 62700, 62701
# 	No Kaon to Tag 62701, 62702
# -> Event 39897 Index 62703 Length 3
# 	No Kaon to Tag 62703, 62704
# 	No Kaon to Tag 62704, 62705
# -> Event 39898 Index 62706 Length 1
# 	KS->2pi
# -> Event 39899 Index 62707 Length 1
# 	KS->2pi
# -> Event 39900 Index 62708 Length 1
# 	KS->2pi
# -> Event 39901 Index 62709 Length 1
# -> Event 39902 Index 62710 Length 1
# 	KS->2pi
# -> Event 39903 Index 62711 Length 1
# -> Event 39904 Index 62712 Length 1
# 	KS->2pi
# -> Event 39905 Index 62713 Length 1
# 	KS->2pi
# -> Event 39906 Index 62714 Length 2
# 	No Kaon to Tag 62714, 62715
# -> Event 39907 Index 62716 Length 2
# 	No Kaon to Tag 62716, 62717
# 	KS -> 2pi
# -> Event 39908 Index 62718 Length 1
# -> Event 39909 Index 62719 Length 1
# 	KS->2pi
# -> Event 39910 Index 62720 Length 2
# 	No Kaon to Tag 62720, 62721
# 	KS -> 2pi
# -> Event 39911 Index 62722 Length 5
# 	No Kaon to Tag 62722, 62725
# 	No Kaon to Tag 62722, 62726
# 	No Kaon to Tag 62723, 62724
# 	No Kaon to Tag 62723, 62725
# 	No Kaon to Tag 62723, 62726
# 	No Kaon to Tag 62724, 62725
# 	No Kaon to Tag 62725, 62726
# 	KS -> 2pi
# -> Event 39912 Index 62727 Length 2
# 	No Kaon to Tag 62727, 62728
# -> Event 39913 Index 62729 Length 1
# -> Event 39914 Index 62730 Length 8
# 	No Kaon to Tag 62730, 62731
# 	No Kaon to Tag 62730, 62732
# 	No Kaon to Tag 62730, 62733
# 	No Kaon to Tag 62730, 62735
# 	No Kaon to Tag 62730, 62736
# 	No Kaon to Tag 62731, 62733
# 	No Kaon to Tag 62731, 62734
# 	No Kaon to Tag 62731, 62735
# 	No Kaon to Tag 62731, 62736
# 	No Kaon to Tag 62731, 62737
# 	No Kaon to Tag 62732, 62733
# 	No Kaon to Tag 62732, 62734
# 	No Kaon to Tag 62732, 62737
# 	No Kaon to Tag 62733, 62735
# 	No Kaon to Tag 62733, 62736
# 	No Kaon to Tag 62734, 62735
# 	No Kaon to Tag 62734, 62736
# 	No Kaon to Tag 62734, 62737
# 	No Kaon to Tag 62735, 62736
# 	No Kaon to Tag 62735, 62737
# 	No Kaon to Tag 62736, 62737
# -> Event 39915 Index 62738 Length 1
# 	KS->2pi
# -> Event 39916 Index 62739 Length 1
# -> Event 39917 Index 62740 Length 8
# 	No Kaon to Tag 62740, 62741
# 	No Kaon to Tag 62740, 62742
# 	No Kaon to Tag 62740, 62744
# 	No Kaon to Tag 62740, 62745
# 	No Kaon to Tag 62740, 62746
# 	No Kaon to Tag 62740, 62747
# 	No Kaon to Tag 62741, 62742
# 	No Kaon to Tag 62741, 62743
# 	No Kaon to Tag 62741, 62744
# 	No Kaon to Tag 62741, 62747
# 	No Kaon to Tag 62742, 62743
# 	No Kaon to Tag 62742, 62744
# 	62745 is a KS, 62742 is a KL
# 	62746 is a KS, 62742 is a KL
# 	No Kaon to Tag 62742, 62747
# 	No Kaon to Tag 62743, 62744
# 	No Kaon to Tag 62743, 62745
# 	No Kaon to Tag 62743, 62746
# 	No Kaon to Tag 62743, 62747
# 	No Kaon to Tag 62744, 62745
# 	No Kaon to Tag 62744, 62746
# 	No Kaon to Tag 62745, 62747
# 	No Kaon to Tag 62746, 62747
# -> Event 39918 Index 62748 Length 1
# 	KS->2pi
# -> Event 39919 Index 62749 Length 1
# -> Event 39920 Index 62750 Length 1
# -> Event 39921 Index 62751 Length 2
# 	No Kaon to Tag 62751, 62752
# -> Event 39922 Index 62753 Length 2
# 	No Kaon to Tag 62753, 62754
# 	KS -> 2pi
# -> Event 39923 Index 62755 Length 2
# 	No Kaon to Tag 62755, 62756
# -> Event 39924 Index 62757 Length 1
# 	KS->2pi
# -> Event 39925 Index 62758 Length 3
# 	No Kaon to Tag 62758, 62759
# 	No Kaon to Tag 62758, 62760
# 	No Kaon to Tag 62759, 62760
# -> Event 39926 Index 62761 Length 2
# -> Event 39927 Index 62763 Length 3
# 	No Kaon to Tag 62763, 62765
# 	No Kaon to Tag 62764, 62765
# -> Event 39928 Index 62766 Length 1
# -> Event 39929 Index 62767 Length 2
# 	No Kaon to Tag 62767, 62768
# 	KS -> 2pi
# -> Event 39930 Index 62769 Length 1
# 	KS->2pi
# -> Event 39931 Index 62770 Length 3
# 	No Kaon to Tag 62770, 62771
# 	No Kaon to Tag 62770, 62772
# 	No Kaon to Tag 62771, 62772
# -> Event 39932 Index 62773 Length 2
# -> Event 39933 Index 62775 Length 1
# -> Event 39934 Index 62776 Length 1
# 	KS->2pi
# -> Event 39935 Index 62777 Length 1
# -> Event 39936 Index 62778 Length 1
# 	KS->2pi
# -> Event 39937 Index 62779 Length 1
# -> Event 39938 Index 62780 Length 2
# 	No Kaon to Tag 62780, 62781
# 	KS -> 2pi
# -> Event 39939 Index 62782 Length 1
# -> Event 39940 Index 62783 Length 1
# 	KS->2pi
# -> Event 39941 Index 62784 Length 1
# -> Event 39942 Index 62785 Length 3
# 	No Kaon to Tag 62785, 62786
# -> Event 39943 Index 62788 Length 3
# 	No Kaon to Tag 62788, 62789
# 	No Kaon to Tag 62789, 62790
# -> Event 39944 Index 62791 Length 2
# -> Event 39945 Index 62793 Length 1
# -> Event 39946 Index 62794 Length 2
# 	62794 is a KS, 62795 is a KL
# 	KS -> 2pi
# -> Event 39947 Index 62796 Length 2
# 	No Kaon to Tag 62796, 62797
# -> Event 39948 Index 62798 Length 1
# 	KS->2pi
# -> Event 39949 Index 62799 Length 1
# -> Event 39950 Index 62800 Length 1
# -> Event 39951 Index 62801 Length 1
# 	KS->2pi
# -> Event 39952 Index 62802 Length 2
# 	No Kaon to Tag 62802, 62803
# -> Event 39953 Index 62804 Length 1
# 	KS->2pi
# -> Event 39954 Index 62805 Length 1
# -> Event 39955 Index 62806 Length 2
# 	No Kaon to Tag 62806, 62807
# 	KS -> 2pi
# -> Event 39956 Index 62808 Length 6
# 	No Kaon to Tag 62808, 62810
# 	No Kaon to Tag 62808, 62811
# 	No Kaon to Tag 62808, 62812
# 	No Kaon to Tag 62808, 62813
# 	No Kaon to Tag 62809, 62811
# 	No Kaon to Tag 62809, 62813
# 	No Kaon to Tag 62810, 62811
# 	No Kaon to Tag 62810, 62812
# 	No Kaon to Tag 62810, 62813
# 	No Kaon to Tag 62811, 62812
# 	No Kaon to Tag 62811, 62813
# 	No Kaon to Tag 62812, 62813
# -> Event 39957 Index 62814 Length 1
# -> Event 39958 Index 62815 Length 2
# 	No Kaon to Tag 62815, 62816
# 	KS -> 2pi
# -> Event 39959 Index 62817 Length 1
# -> Event 39960 Index 62818 Length 1
# 	KS->2pi
# -> Event 39961 Index 62819 Length 2
# 	No Kaon to Tag 62819, 62820
# 	KS -> 2pi
# -> Event 39962 Index 62821 Length 1
# 	KS->2pi
# -> Event 39963 Index 62822 Length 2
# 	No Kaon to Tag 62822, 62823
# 	KS -> 2pi
# -> Event 39964 Index 62824 Length 1
# 	KS->2pi
# -> Event 39965 Index 62825 Length 1
# 	KS->2pi
# -> Event 39966 Index 62826 Length 1
# 	KS->2pi
# -> Event 39967 Index 62827 Length 2
# -> Event 39968 Index 62829 Length 2
# -> Event 39969 Index 62831 Length 1
# -> Event 39970 Index 62832 Length 2
# 	62832 is a KS, 62833 is a KL
# -> Event 39971 Index 62834 Length 2
# 	62834 is a KS, 62835 is a KL
# 	KS -> 2pi
# -> Event 39972 Index 62836 Length 1
# 	KS->2pi
# -> Event 39973 Index 62837 Length 2
# -> Event 39974 Index 62839 Length 2
# 	No Kaon to Tag 62839, 62840
# 	KS -> 2pi
# -> Event 39975 Index 62841 Length 2
# -> Event 39976 Index 62843 Length 1
# 	KS->2pi
# -> Event 39977 Index 62844 Length 2
# 	No Kaon to Tag 62844, 62845
# 	KS -> 2pi
# -> Event 39978 Index 62846 Length 1
# -> Event 39979 Index 62847 Length 1
# 	KS->2pi
# -> Event 39980 Index 62848 Length 1
# 	KS->2pi
# -> Event 39981 Index 62849 Length 2
# 	No Kaon to Tag 62849, 62850
# 	KS -> 2pi
# -> Event 39982 Index 62851 Length 1
# -> Event 39983 Index 62852 Length 1
# -> Event 39984 Index 62853 Length 3
# 	No Kaon to Tag 62853, 62854
# 	No Kaon to Tag 62853, 62855
# 	No Kaon to Tag 62854, 62855
# -> Event 39985 Index 62856 Length 3
# 	No Kaon to Tag 62856, 62857
# -> Event 39986 Index 62859 Length 2
# 	No Kaon to Tag 62859, 62860
# -> Event 39987 Index 62861 Length 1
# -> Event 39988 Index 62862 Length 1
# -> Event 39989 Index 62863 Length 1
# -> Event 39990 Index 62864 Length 3
# 	No Kaon to Tag 62864, 62865
# 	No Kaon to Tag 62865, 62866
# 	KS -> 2pi
# -> Event 39991 Index 62867 Length 1
# 	KS->2pi
# -> Event 39992 Index 62868 Length 1
# 	KS->2pi
# -> Event 39993 Index 62869 Length 3
# 	No Kaon to Tag 62869, 62870
# 	No Kaon to Tag 62869, 62871
# 	No Kaon to Tag 62870, 62871
# -> Event 39994 Index 62872 Length 2
# 	No Kaon to Tag 62872, 62873
# -> Event 39995 Index 62874 Length 1
# -> Event 39996 Index 62875 Length 1
# 	KS->2pi
# -> Event 39997 Index 62876 Length 2
# 	No Kaon to Tag 62876, 62877
# -> Event 39998 Index 62878 Length 4
# 	No Kaon to Tag 62878, 62879
# 	No Kaon to Tag 62878, 62880
# 	No Kaon to Tag 62878, 62881
# 	No Kaon to Tag 62879, 62880
# 	No Kaon to Tag 62879, 62881
# 	No Kaon to Tag 62880, 62881
# -> Event 39999 Index 62882 Length 1
# -> Event 40000 Index 62883 Length 1
# 	KS->2pi
# -> Event 40001 Index 62884 Length 2
# 	No Kaon to Tag 62884, 62885
# -> Event 40002 Index 62886 Length 1
# 	KS->2pi
# -> Event 40003 Index 62887 Length 1
# -> Event 40004 Index 62888 Length 5
# 	No Kaon to Tag 62888, 62889
# 	No Kaon to Tag 62888, 62890
# 	No Kaon to Tag 62888, 62891
# 	No Kaon to Tag 62889, 62890
# 	No Kaon to Tag 62889, 62892
# 	No Kaon to Tag 62890, 62892
# 	No Kaon to Tag 62891, 62892
# -> Event 40005 Index 62893 Length 1
# -> Event 40006 Index 62894 Length 1
# -> Event 40007 Index 62895 Length 2
# 	No Kaon to Tag 62895, 62896
# 	KS -> 2pi
# -> Event 40008 Index 62897 Length 1
# -> Event 40009 Index 62898 Length 2
# -> Event 40010 Index 62900 Length 2
# 	No Kaon to Tag 62900, 62901
# -> Event 40011 Index 62902 Length 1
# 	KS->2pi
# -> Event 40012 Index 62903 Length 2
# 	No Kaon to Tag 62903, 62904
# 	KS -> 2pi
# -> Event 40013 Index 62905 Length 2
# 	No Kaon to Tag 62905, 62906
# 	KS -> 2pi
# -> Event 40014 Index 62907 Length 1
# -> Event 40015 Index 62908 Length 1
# 	KS->2pi
# -> Event 40016 Index 62909 Length 1
# 	KS->2pi
# -> Event 40017 Index 62910 Length 1
# -> Event 40018 Index 62911 Length 1
# -> Event 40019 Index 62912 Length 1
# -> Event 40020 Index 62913 Length 1
# 	KS->2pi
# -> Event 40021 Index 62914 Length 2
# 	No Kaon to Tag 62914, 62915
# -> Event 40022 Index 62916 Length 3
# 	No Kaon to Tag 62916, 62917
# 	No Kaon to Tag 62916, 62918
# 	No Kaon to Tag 62917, 62918
# 	KS -> 2pi
# -> Event 40023 Index 62919 Length 1
# -> Event 40024 Index 62920 Length 2
# -> Event 40025 Index 62922 Length 3
# 	No Kaon to Tag 62922, 62923
# 	No Kaon to Tag 62923, 62924
# -> Event 40026 Index 62925 Length 2
# 	No Kaon to Tag 62925, 62926
# 	KS -> 2pi
# -> Event 40027 Index 62927 Length 1
# -> Event 40028 Index 62928 Length 1
# 	KS->2pi
# -> Event 40029 Index 62929 Length 1
# 	KS->2pi
# -> Event 40030 Index 62930 Length 1
# 	KS->2pi
# -> Event 40031 Index 62931 Length 1
# 	KS->2pi
# -> Event 40032 Index 62932 Length 2
# 	No Kaon to Tag 62932, 62933
# -> Event 40033 Index 62934 Length 1
# 	KS->2pi
# -> Event 40034 Index 62935 Length 1
# -> Event 40035 Index 62936 Length 2
# 	No Kaon to Tag 62936, 62937
# -> Event 40036 Index 62938 Length 1
# -> Event 40037 Index 62939 Length 1
# -> Event 40038 Index 62940 Length 1
# 	KS->2pi
# -> Event 40039 Index 62941 Length 2
# 	No Kaon to Tag 62941, 62942
# -> Event 40040 Index 62943 Length 1
# 	KS->2pi
# -> Event 40041 Index 62944 Length 2
# 	No Kaon to Tag 62944, 62945
# -> Event 40042 Index 62946 Length 4
# 	No Kaon to Tag 62946, 62947
# 	No Kaon to Tag 62946, 62948
# 	No Kaon to Tag 62946, 62949
# 	No Kaon to Tag 62947, 62948
# 	No Kaon to Tag 62947, 62949
# -> Event 40043 Index 62950 Length 3
# 	No Kaon to Tag 62950, 62951
# 	No Kaon to Tag 62950, 62952
# 	No Kaon to Tag 62951, 62952
# -> Event 40044 Index 62953 Length 2
# 	62953 is a KS, 62954 is a KL
# 	KS -> 2pi
# -> Event 40045 Index 62955 Length 1
# 	KS->2pi
# -> Event 40046 Index 62956 Length 1
# 	KS->2pi
# -> Event 40047 Index 62957 Length 1
# -> Event 40048 Index 62958 Length 1
# 	KS->2pi
# -> Event 40049 Index 62959 Length 3
# 	No Kaon to Tag 62959, 62960
# 	No Kaon to Tag 62959, 62961
# 	No Kaon to Tag 62960, 62961
# 	KS -> 2pi
# -> Event 40050 Index 62962 Length 2
# 	62962 is a KS, 62963 is a KL
# 	KS -> 2pi
# -> Event 40051 Index 62964 Length 1
# -> Event 40052 Index 62965 Length 2
# 	No Kaon to Tag 62965, 62966
# -> Event 40053 Index 62967 Length 1
# -> Event 40054 Index 62968 Length 1
# 	KS->2pi
# -> Event 40055 Index 62969 Length 3
# 	No Kaon to Tag 62969, 62970
# 	No Kaon to Tag 62969, 62971
# 	No Kaon to Tag 62970, 62971
# 	KS -> 2pi
# -> Event 40056 Index 62972 Length 2
# 	No Kaon to Tag 62972, 62973
# -> Event 40057 Index 62974 Length 2
# 	No Kaon to Tag 62974, 62975
# 	KS -> 2pi
# -> Event 40058 Index 62976 Length 2
# 	No Kaon to Tag 62976, 62977
# 	KS -> 2pi
# -> Event 40059 Index 62978 Length 1
# 	KS->2pi
# -> Event 40060 Index 62979 Length 1
# -> Event 40061 Index 62980 Length 1
# 	KS->2pi
# -> Event 40062 Index 62981 Length 3
# 	No Kaon to Tag 62981, 62982
# 	No Kaon to Tag 62981, 62983
# 	No Kaon to Tag 62982, 62983
# -> Event 40063 Index 62984 Length 3
# 	No Kaon to Tag 62984, 62985
# 	No Kaon to Tag 62984, 62986
# -> Event 40064 Index 62987 Length 1
# -> Event 40065 Index 62988 Length 2
# 	62988 is a KS, 62989 is a KL
# -> Event 40066 Index 62990 Length 1
# -> Event 40067 Index 62991 Length 1
# -> Event 40068 Index 62992 Length 1
# -> Event 40069 Index 62993 Length 1
# -> Event 40070 Index 62994 Length 1
# -> Event 40071 Index 62995 Length 1
# 	KS->2pi
# -> Event 40072 Index 62996 Length 2
# -> Event 40073 Index 62998 Length 1
# -> Event 40074 Index 62999 Length 1
# 	KS->2pi
# -> Event 40075 Index 63000 Length 1
# -> Event 40076 Index 63001 Length 1
# 	KS->2pi
# -> Event 40077 Index 63002 Length 3
# 	No Kaon to Tag 63002, 63003
# 	No Kaon to Tag 63002, 63004
# -> Event 40078 Index 63005 Length 1
# -> Event 40079 Index 63006 Length 3
# 	No Kaon to Tag 63006, 63007
# 	No Kaon to Tag 63006, 63008
# 	No Kaon to Tag 63007, 63008
# 	KS -> 2pi
# -> Event 40080 Index 63009 Length 1
# 	KS->2pi
# -> Event 40081 Index 63010 Length 1
# 	KS->2pi
# -> Event 40082 Index 63011 Length 2
# 	No Kaon to Tag 63011, 63012
# -> Event 40083 Index 63013 Length 1
# 	KS->2pi
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ks = KS_2pi/(my.epsS*my.BR_KS_2pi)
int(ks), KS_2pi, N_KS_measured
# Out:
# (188068, 90837, 98532.0)

# %%
kl_cp = KL_CP/(my.acceptance*my.epsL)
kl_cp, KL_CP, N_KL_CP_measured
# Out:
# (432.0, 54, 51.00000000000001)

# %%
rel_sigma = np.sqrt((KL_CP/KL_CP**2))
sigma_cp = rel_sigma*kl_cp

# %%
rel_sigma_S = np.sqrt((KS_2pi/KS_2pi**2))
sigma_ks = rel_sigma_S*ks

# %%
BR = int(kl_cp)/(int(ks))
sigma_BR = np.sqrt((rel_sigma_S)**2 + (rel_sigma)**2) * BR

# %%
print(f'BR = {BR:.4f} +/- {sigma_BR:.4f}')
# Out:
# BR = 0.0023 +/- 0.0003

# %%
BR = kl_cp/N_KLKS
sigma_BR = np.sqrt((rel_sigma)**2) * BR
print(f'BR = {BR:.4f} +/- {sigma_BR:.4f}')
# Out:
# BR = 0.0021 +/- 0.0003

# %%
length = []
for i, eve in enumerate(events):                                             # Loop through events
    
    length.append(ext_events[i+1]-ext_events[i])

# %%
# plt.hist(length, histtype = 'step', align = 'left');
plt.bar(*np.unique(length, return_counts=True), fill = False, edgecolor = 'blue')
# plt.ylim(0,5000)
plt.xlabel('Event Length')
plt.ylabel('Counts')
plt.savefig('Event_Length.jpg', dpi = 300)
